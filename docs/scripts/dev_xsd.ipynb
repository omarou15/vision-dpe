# %% [markdown]
# # diff excel/XSD

# %%
WRITE_IN_PLACE = True

# %%
from lxml.etree import SubElement
from pathlib import Path
import pandas as pd
import numpy as np
import json

# %%
def reformat(x):
    x=x.lower().strip()
    x = ' '.join(x.split())
    return x

def reformat_dict(d):
    d=d.copy()
    for k,v in d.items():
        d[k]=reformat(v)
    return d

# %%
from lxml import etree

# %%
import xmlschema

# %%
path_schema = r'D:\Cstbdata\MONWORKSPACE\Gitlab\observatoire-dpe\modele_donnee\fusion_DPE_AUDIT.xsd'
# schema = etree.XMLSchema(
#                 file=path_schema) 
schema = xmlschema.XMLSchema11(path_schema)
parser = etree.XMLParser(remove_blank_text=True)
dpe_neuf = etree.parse(r'D:\Cstbdata\MONWORKSPACE\Gitlab\observatoire-dpe\modele_donnee\exemples_metier\cas_test_appt_2_neuf_valid.xml')
dpe = etree.parse(r'D:\Cstbdata\MONWORKSPACE\Gitlab\observatoire-dpe\modele_donnee\exemples_metier\cas_test_immeuble_1_valid_avec_reference.xml')

audit = etree.parse(r'D:\Cstbdata\MONWORKSPACE\Gitlab\observatoire-dpe\modele_donnee_audit\exemples_metier\cas_test_audit_maison_1_v0.xml')



schema.is_valid(audit)


schema.is_valid(dpe)

schema.validate(dpe)

schema.is_valid(dpe_neuf)

# %%
path_schema = r'D:\Cstbdata\MONWORKSPACE\Gitlab\observatoire-dpe\modele_donnee\test_mur.xsd'
schema = xmlschema.XMLSchema11(path_schema)

parser = etree.XMLParser(remove_blank_text=True)
mur = etree.parse(r'D:\Cstbdata\MONWORKSPACE\Gitlab\observatoire-dpe\modele_donnee\test_mur.xml')

schema.validate(mur)
# Out:
# ---------------------------------------------------------------------------
# XMLSchemaChildrenValidationError          Traceback (most recent call last)
# <ipython-input-41-1449741a9568> in <module>
#       5 mur = etree.parse(r'D:\Cstbdata\MONWORKSPACE\Gitlab\observatoire-dpe\modele_donnee\test_mur.xml')
#       6
# ----> 7 schema.validate(mur)
#       8
#       9
#
# C:\LogicielsCstb\Anaconda3\lib\site-packages\xmlschema\validators\schemas.py in validate(self, source, path, schema_path, use_defaults, namespaces, max_depth, extra_validator)
#    1676         for error in self.iter_errors(source, path, schema_path, use_defaults,
#    1677                                       namespaces, max_depth, extra_validator):
# -> 1678             raise error
#    1679
#    1680     def is_valid(self, source: Union[XMLSourceType, XMLResource],
#
# XMLSchemaChildrenValidationError: failed validating <Element donnee_entree at 0x2e4d3e67600> with Xsd11Group(model='sequence', occurs=[1, 1]):
#
# Reason: Unexpected child with tag 'toto' at position 4.
#
# Schema:
#
#   <xs:complexType xmlns:xs="http://www.w3.org/2001/XMLSchema" name="ChildDonneeEntreeMur">
#       <xs:complexContent>
#           <xs:extension base="DonneeEntreeMur">
#               <xs:sequence>
#                   <xs:element name="surface_paroi_opaque">
#                       <xs:annotation>
#                           <xs:documentation>Surface de paroi opaque (sans baies vitrées sans portes)</xs:documentation>
#                           <xs:appinfo source="dpe/logement/enveloppe/mur_collection/mur/donnee_entree/surface_paroi_opaque" />
#                       </xs:annotation>
#                       <xs:simpleType>
#                           <xs:restriction base="xs:double">
#                               <xs:minExclusive value="0" />
#                           </xs:restriction>
#                       </xs:simpleType>
#                   </xs:element>
#               </xs:sequence>
#           </xs:extension>
#       </xs:complexContent>
#   </xs:complexType>
#
# Instance (line 2):
#
#   <donnee_entree>
#       <description>mur adjacent</description>
#       <reference>x04642</reference>
#       <surface_paroi_opaque>500.4</surface_paroi_opaque>
#       <toto>1</toto>
#   </donnee_entree>
#
# Path: /mur/donnee_entree

# %%
schema.validation_error(mur)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-92dba9b73e16> in <module>
# ----> 1 schema.validation_error(mur)
#
# TypeError: validation_error() missing 1 required positional argument: 'error'

# %%
schema.
# Out:
# XMLSchema11(name='test_mur.xsd', namespace='')

# %%
import xmlschema

# %%
schema = xmlschema.XMLSchema11(path_schema)
parser = etree.XMLParser(remove_blank_text=True)
mur = etree.parse(r'D:\Cstbdata\MONWORKSPACE\Gitlab\observatoire-dpe\modele_donnee\test_mur.xml')
schema.is_valid(mur)
# Out:
# True

# %%
schema.validation_error(mur)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-92dba9b73e16> in <module>
# ----> 1 schema.validation_error(mur)
#
# TypeError: validation_error() missing 1 required positional argument: 'error'

# %%
schema.validate?

# %%
# !pip install xmlschema
# Out:
# Collecting xmlschema
#   Downloading xmlschema-1.10.0-py3-none-any.whl (273 kB)
# Collecting elementpath<3.0.0,>=2.5.0
#   Downloading elementpath-2.5.1-py3-none-any.whl (181 kB)
# Installing collected packages: elementpath, xmlschema
# Successfully installed elementpath-2.5.1 xmlschema-1.10.0

# %% [markdown]
# ## heritage non explicite

# %%
from lxml.etree import SubElement
from pathlib import Path

xs = '{http://www.w3.org/2001/XMLSchema}'
namespaces = {'xs': 'http://www.w3.org/2001/XMLSchema',
             'obsdpe':"https://gitlab.com/observatoire-dpe/observatoire-dpe/modele_donnee"}

path_xsd = r'..\modele_donnee\temp.xsd'
# path_xsd = r'.\DPE_dev.xsd'
write_path = str((Path(path_xsd).parent/'temp_write.xsd').absolute())
parser = etree.XMLParser(remove_blank_text=True)

et = etree.parse(path_xsd, parser)
root = et.getroot()
all_el = list(root.iterfind('*//xs:element', namespaces=namespaces))

# %%
root.nsmap
# Out:
# {'xs': 'http://www.w3.org/2001/XMLSchema',
#  'vc': 'http://www.w3.org/2007/XMLSchema-versioning',
#  'xsi': 'http://www.w3.org/2001/XMLSchema-instance',
#  'obsdpe': 'https://gitlab.com/observatoire-dpe/observatoire-dpe/modele_donnee'}

# %%
appinfo_generic = etree.Element(f"{xs}appinfo")
annotation_generic = etree.Element(f"{xs}annotation")
documentation_generic = etree.Element(f"{xs}documentation")

# %%
def build_annotation(el):
    annotation = el.find('xs:annotation', namespaces=namespaces)
    if annotation is  None:
        annotation = copy.copy(annotation_generic)
        el.insert(0,annotation)
    appinfo = annotation.find('xs:appinfo',namespaces=namespaces)
    if appinfo is None:
        appinfo=copy.copy(appinfo_generic)
        annotation.insert(0,appinfo)
    documentation = annotation.find('xs:documentation',namespaces=namespaces)
    if documentation is None:
        documentation=copy.copy(documentation_generic)
        annotation.append(documentation)
    return el

# %%
namespaces
# Out:
# {'xs': 'http://www.w3.org/2001/XMLSchema',
#  'obsdpe': 'https://gitlab.com/observatoire-dpe/observatoire-dpe/modele_donnee'}

# %%
model_usage='{https://gitlab.com/observatoire-dpe/observatoire-dpe/modele_donnee}model_usage'

# %% [markdown]
# ### logement

# %%
for el in all_el:
    
#     el = build_annotation(el)
#     annotation = el.find('xs:annotation', namespaces=namespaces)
#     appinfo = annotation.find('xs:appinfo',namespaces=namespaces)

        
    if el.attrib['name'] not in ['enum_scenario_id','enum_etape_id','nom_scenario','enum_etat_composant_id']:
        el.attrib[model_usage]="common"
            
    else:
        el.attrib[model_usage]='audit'

etape_travaux=root.xpath('//xs:element[@name="etape_travaux"]', namespaces=namespaces)[0]
etape_travaux.attrib[model_usage]='audit'

for el in etape_travaux.iterfind('*//xs:element', namespaces=namespaces):

    el.attrib[model_usage]='audit'

# %% [markdown]
# ### admin

# %%
admin_specific_audit=[
"auditeur",
"date_visite_auditeur",
"date_etablissement_audit",
"numero_dpe",
"audit_a_remplacer",
"enum_version_audit_id",
"enum_modele_audit_id",
"enum_derogation_technique_id",
"derogation_technique_detail",
"enum_derogation_economique_id",
"derogation_economique_detail",
                     ]
admin_specific_dpe=[
    
"dpe_a_remplacer",
"dpe_immeuble_associe",
"enum_version_id",
"date_visite_diagnostiqueur",
"date_etablissement_dpe",
"enum_modele_dpe_id",
"diagnostiqueur",
]

# %%
for el in all_el:
    
#     el = build_annotation(el)
#     annotation = el.find('xs:annotation', namespaces=namespaces)
#     appinfo = annotation.find('xs:appinfo',namespaces=namespaces)

        
    if el.attrib['name']  in admin_specific_audit:
        el.attrib[model_usage]="audit"
    elif el.attrib['name'] in admin_specific_dpe:
        el.attrib[model_usage]="dpe"
    else:
        el.attrib[model_usage]='common'

diagnostiqueur=root.xpath('//xs:element[@name="diagnostiqueur"]', namespaces=namespaces)[0]
diagnostiqueur.attrib[model_usage]='dpe'

for el in diagnostiqueur.iterfind('*//xs:element', namespaces=namespaces):

    el.attrib[model_usage]='dpe'

    
auditeur=root.xpath('//xs:element[@name="auditeur"]', namespaces=namespaces)[0]
auditeur.attrib[model_usage]='dpe'

for el in auditeur.iterfind('*//xs:element', namespaces=namespaces):

    el.attrib[model_usage]='audit'

# %%
# for el in all_el:
    
#     el = build_annotation(el)
#     annotation = el.find('xs:annotation', namespaces=namespaces)
#     appinfo = annotation.find('xs:appinfo',namespaces=namespaces)

        
#     if el.attrib['name'] not in ['enum_scenario_id','enum_etape_id','nom_scenario','enum_etat_composant_id']:
#         appinfo.attrib['model']="common"
            
#     else:
#         appinfo.attrib['model']='audit'

# etape_travaux=root.xpath('//xs:element[@name="etape_travaux"]', namespaces=namespaces)[0]
# etape_travaux.attrib['model']='audit'
# etape_travaux=build_annotation(etape_travaux)
# annotation = etape_travaux.find('xs:annotation', namespaces=namespaces)
# appinfo = annotation.find('xs:appinfo',namespaces=namespaces)
# for el in etape_travaux.iterfind('*//xs:element', namespaces=namespaces):
#     el = build_annotation(el)
#     annotation = el.find('xs:annotation', namespaces=namespaces)
#     appinfo = annotation.find('xs:appinfo',namespaces=namespaces)

#     appinfo.attrib['model']='audit'

# %%
et.write(write_path, pretty_print=True, xml_declaration=True, encoding='utf-8')

# %% [markdown]
# ### test

# %%
path_schema = r'D:\Cstbdata\MONWORKSPACE\Gitlab\observatoire-dpe\modele_donnee\fusion_DPE_AUDIT_heritage_non_explicite.xsd'
# schema = etree.XMLSchema(
#                 file=path_schema) 
schema = xmlschema.XMLSchema11(path_schema)

# %%
path_schema = r'D:\Cstbdata\MONWORKSPACE\Gitlab\observatoire-dpe\modele_donnee\fusion_DPE_AUDIT_heritage_non_explicite.xsd'
schema = etree.XMLSchema(
                file=path_schema) 
# schema = xmlschema.XMLSchema11(path_schema)
parser = etree.XMLParser(remove_blank_text=True)
dpe_neuf = etree.parse(r'D:\Cstbdata\MONWORKSPACE\Gitlab\observatoire-dpe\modele_donnee\exemples_metier\cas_test_appt_2_neuf_valid.xml')
dpe = etree.parse(r'D:\Cstbdata\MONWORKSPACE\Gitlab\observatoire-dpe\modele_donnee\exemples_metier\cas_test_immeuble_1_valid_avec_reference.xml')

audit = etree.parse(r'D:\Cstbdata\MONWORKSPACE\Gitlab\observatoire-dpe\modele_donnee_audit\exemples_metier\cas_test_audit_maison_1_v0.xml')



schema.validate(audit)
# Out:
# False

# %%
schema.error_log
# Out:
# file:/D:/Cstbdata/MONWORKSPACE/Gitlab/observatoire-dpe/modele_donnee_audit/exemples_metier/cas_test_audit_maison_1_v0.xml:3:0:ERROR:SCHEMASV:SCHEMAV_ELEMENT_CONTENT: Element 'administratif_audit': This element is not expected. Expected is ( administratif ).

# %%
schema.validate(dpe)
schema.error_log
# Out:
# file:/D:/Cstbdata/MONWORKSPACE/Gitlab/observatoire-dpe/modele_donnee/exemples_metier/cas_test_immeuble_1_valid_avec_reference.xml:101:0:ERROR:SCHEMASV:SCHEMAV_ELEMENT_CONTENT: Element 'caracteristique_generale': Missing child element(s). Expected is one of ( surface_habitable_logement, nombre_niveau_logement, surface_tertiaire_immeuble, appartement_non_visite, enum_scenario_id, enum_etape_id, nom_scenario ).
# file:/D:/Cstbdata/MONWORKSPACE/Gitlab/observatoire-dpe/modele_donnee/exemples_metier/cas_test_immeuble_1_valid_avec_reference.xml:124:0:ERROR:SCHEMASV:SCHEMAV_ELEMENT_CONTENT: Element 'donnee_entree': Missing child element(s). Expected is one of ( surface_aiu, surface_aue, enum_cfg_isolation_lnc_id, tv_umur0_id, umur_saisi, enum_periode_isolation_id, tv_umur_id, enum_etat_composant_id ).
# file:/D:/Cstbdata/MONWORKSPACE/Gitlab/observatoire-dpe/modele_donnee/exemples_metier/cas_test_immeuble_1_valid_avec_reference.xml:150:0:ERROR:SCHEMASV:SCHEMAV_ELEMENT_CONTENT: Element 'donnee_entree': Missing child element(s). Expected is one of ( umur0_saisi, umur_saisi, enum_periode_isolation_id, resistance_isolation, epaisseur_isolation, enum_etat_composant_id ).
# file:/D:/Cstbdata/MONWORKSPACE/Gitlab/observatoire-dpe/modele_donnee/exemples_metier/cas_test_immeuble_1_valid_avec_reference.xml:178:0:ERROR:SCHEMASV:SCHEMAV_ELEMENT_CONTENT: Element 'donnee_entree': Missing child element(s). Expected is one of ( umur0_saisi, umur_saisi, enum_periode_isolation_id, resistance_isolation, epaisseur_isolation, tv_umur_id, enum_etat_composant_id ).
# file:/D:/Cstbdata/MONWORKSPACE/Gitlab/observatoire-dpe/modele_donnee/exemples_metier/cas_test_immeuble_1_valid_avec_reference.xml:207:0:ERROR:SCHEMASV:SCHEMAV_ELEMENT_CONTENT: Element 'donnee_entree': Missing child element(s). Expected is one of ( surface_aiu, surface_aue, enum_cfg_isolation_lnc_id, upb0_saisi, upb_saisi, resistance_isolation, epaisseur_isolation, surface_ue, enum_etat_composant_id ).
# file:/D:/Cstbdata/MONWORKSPACE/Gitlab/observatoire-dpe/modele_donnee/exemples_metier/cas_test_immeuble_1_valid_avec_reference.xml:234:0:ERROR:SCHEMASV:SCHEMAV_ELEMENT_CONTENT: Element 'donnee_entree': Missing child element(s). Expected is one of ( uph0_saisi, uph_saisi, resistance_isolation, epaisseur_isolation, enum_etat_composant_id ).
# file:/D:/Cstbdata/MONWORKSPACE/Gitlab/observatoire-dpe/modele_donnee/exemples_metier/cas_test_immeuble_1_valid_avec_reference.xml:260:0:ERROR:SCHEMASV:SCHEMAV_ELEMENT_CONTENT: Element 'donnee_entree': Missing child element(s). Expected is one of ( surface_aiu, surface_aue, enum_cfg_isolation_lnc_id, enum_type_gaz_lame_id, epaisseur_lame, vitrage_vir, ug_saisi, uw_saisi, uw_1, sw_1 ).
# file:/D:/Cstbdata/MONWORKSPACE/Gitlab/observatoire-dpe/modele_donnee/exemples_metier/cas_test_immeuble_1_valid_avec_reference.xml:309:0:ERROR:SCHEMASV:SCHEMAV_ELEMENT_CONTENT: Element 'donnee_entree': Missing child element(s). Expected is one of ( surface_aiu, surface_aue, enum_cfg_isolation_lnc_id, enum_type_gaz_lame_id, epaisseur_lame, vitrage_vir, ug_saisi, uw_saisi, uw_1, sw_1 ).
# file:/D:/Cstbdata/MONWORKSPACE/Gitlab/observatoire-dpe/modele_donnee/exemples_metier/cas_test_immeuble_1_valid_avec_reference.xml:363:0:ERROR:SCHEMASV:SCHEMAV_ELEMENT_CONTENT: Element 'donnee_entree': Missing child element(s). Expected is one of ( surface_aiu, surface_aue, uporte_saisi, nb_porte, largeur_dormant, presence_retour_isolation, enum_etat_composant_id ).
# file:/D:/Cstbdata/MONWORKSPACE/Gitlab/observatoire-dpe/modele_donnee/exemples_metier/cas_test_immeuble_1_valid_avec_reference.xml:384:0:ERROR:SCHEMASV:SCHEMAV_ELEMENT_CONTENT: Element 'donnee_entree': Missing child element(s). Expected is ( enum_etat_composant_id ).
# file:/D:/Cstbdata/MONWORKSPACE/Gitlab/observatoire-dpe/modele_donnee/exemples_metier/cas_test_immeuble_1_valid_avec_reference.xml:398:0:ERROR:SCHEMASV:SCHEMAV_ELEMENT_CONTENT: Element 'donnee_entree': Missing child element(s). Expected is one of ( description, enum_etat_composant_id ).
# file:/D:/Cstbdata/MONWORKSPACE/Gitlab/observatoire-dpe/modele_donnee/exemples_metier/cas_test_immeuble_1_valid_avec_reference.xml:411:0:ERROR:SCHEMASV:SCHEMAV_ELEMENT_CONTENT: Element 'donnee_entree': Missing child element(s). Expected is one of ( reference_2, pourcentage_valeur_pont_thermique, k_saisi, enum_etat_composant_id ).
# file:/D:/Cstbdata/MONWORKSPACE/Gitlab/observatoire-dpe/modele_donnee/exemples_metier/cas_test_immeuble_1_valid_avec_reference.xml:425:0:ERROR:SCHEMASV:SCHEMAV_ELEMENT_CONTENT: Element 'donnee_entree': Missing child element(s). Expected is one of ( pourcentage_valeur_pont_thermique, k_saisi, enum_etat_composant_id ).
# file:/D:/Cstbdata/MONWORKSPACE/Gitlab/observatoire-dpe/modele_donnee/exemples_metier/cas_test_immeuble_1_valid_avec_reference.xml:440:0:ERROR:SCHEMASV:SCHEMAV_ELEMENT_CONTENT: Element 'donnee_entree': Missing child element(s). Expected is one of ( pourcentage_valeur_pont_thermique, k_saisi, enum_etat_composant_id ).
# file:/D:/Cstbdata/MONWORKSPACE/Gitlab/observatoire-dpe/modele_donnee/exemples_metier/cas_test_immeuble_1_valid_avec_reference.xml:455:0:ERROR:SCHEMASV:SCHEMAV_ELEMENT_CONTENT: Element 'donnee_entree': Missing child element(s). Expected is one of ( pourcentage_valeur_pont_thermique, k_saisi, enum_etat_composant_id ).
# file:/D:/Cstbdata/MONWORKSPACE/Gitlab/observatoire-dpe/modele_donnee/exemples_metier/cas_test_immeuble_1_valid_avec_reference.xml:470:0:ERROR:SCHEMASV:SCHEMAV_ELEMENT_CONTENT: Element 'donnee_entree': Missing child element(s). Expected is one of ( pourcentage_valeur_pont_thermique, k_saisi, enum_etat_composant_id ).
# file:/D:/Cstbdata/MONWORKSPACE/Gitlab/observatoire-dpe/modele_donnee/exemples_metier/cas_test_immeuble_1_valid_avec_reference.xml:488:0:ERROR:SCHEMASV:SCHEMAV_ELEMENT_CONTENT: Element 'donnee_entree': Missing child element(s). Expected is one of ( q4pa_conv_saisi, ref_produit_ventilation, cle_repartition_ventilation, enum_etat_composant_id ).
# file:/D:/Cstbdata/MONWORKSPACE/Gitlab/observatoire-dpe/modele_donnee/exemples_metier/cas_test_immeuble_1_valid_avec_reference.xml:509:0:ERROR:SCHEMASV:SCHEMAV_ELEMENT_CONTENT: Element 'donnee_entree': Missing child element(s). Expected is one of ( cle_repartition_clim, enum_etat_composant_id ).
# file:/D:/Cstbdata/MONWORKSPACE/Gitlab/observatoire-dpe/modele_donnee/exemples_metier/cas_test_immeuble_1_valid_avec_reference.xml:531:0:ERROR:SCHEMASV:SCHEMAV_ELEMENT_CONTENT: Element 'donnee_entree': Missing child element(s). Expected is ( enum_etat_composant_id ).
# file:/D:/Cstbdata/MONWORKSPACE/Gitlab/observatoire-dpe/modele_donnee/exemples_metier/cas_test_immeuble_1_valid_avec_reference.xml:554:0:ERROR:SCHEMASV:SCHEMAV_ELEMENT_CONTENT: Element 'donnee_entree': Missing child element(s). Expected is one of ( ratio_virtualisation, cle_repartition_ecs, fecs_saisi, reseau_distribution_isole, enum_etat_composant_id ).
# file:/D:/Cstbdata/MONWORKSPACE/Gitlab/observatoire-dpe/modele_donnee/exemples_metier/cas_test_immeuble_1_valid_avec_reference.xml:580:0:ERROR:SCHEMASV:SCHEMAV_ELEMENT_CONTENT: Element 'donnee_entree': Missing child element(s). Expected is one of ( tv_generateur_combustion_id, tv_scop_id, enum_periode_installation_ecs_thermo_id, identifiant_reseau_chaleur, tv_reseau_chaleur_id, presence_ventouse, enum_etat_composant_id ).
# file:/D:/Cstbdata/MONWORKSPACE/Gitlab/observatoire-dpe/modele_donnee/exemples_metier/cas_test_immeuble_1_valid_avec_reference.xml:607:0:ERROR:SCHEMASV:SCHEMAV_ELEMENT_CONTENT: Element 'donnee_entree': Missing child element(s). Expected is one of ( nombre_logement_echantillon, ratio_virtualisation, coef_ifc, cle_repartition_ch, enum_methode_saisie_fact_couv_sol_id, tv_facteur_couverture_solaire_id, fch_saisi, enum_etat_composant_id ).
# file:/D:/Cstbdata/MONWORKSPACE/Gitlab/observatoire-dpe/modele_donnee/exemples_metier/cas_test_immeuble_1_valid_avec_reference.xml:624:0:ERROR:SCHEMASV:SCHEMAV_ELEMENT_CONTENT: Element 'donnee_entree': Missing child element(s). Expected is one of ( ref_produit_generateur_ch, tv_rendement_generation_id, tv_scop_id, tv_temp_fonc_100_id, tv_temp_fonc_30_id, tv_reseau_chaleur_id, identifiant_reseau_chaleur, n_radiateurs_gaz, priorite_generateur_cascade, enum_etat_composant_id ).
# file:/D:/Cstbdata/MONWORKSPACE/Gitlab/observatoire-dpe/modele_donnee/exemples_metier/cas_test_immeuble_1_valid_avec_reference.xml:653:0:ERROR:SCHEMASV:SCHEMAV_ELEMENT_CONTENT: Element 'donnee_entree': Missing child element(s). Expected is one of ( reseau_distribution_isole, enum_periode_installation_emetteur_id, enum_etat_composant_id ).

# %% [markdown]
# ## autotype everything

# %%
from lxml.etree import SubElement
from pathlib import Path

xs = '{http://www.w3.org/2001/XMLSchema}'
namespaces = {'xs': 'http://www.w3.org/2001/XMLSchema'}

path_xsd = r'..\modele_donnee\fusion_DPE_AUDIT.xsd'
# path_xsd = r'.\DPE_dev.xsd'
write_path = str((Path(path_xsd).parent/'test_fusion_DPE_AUDIT.xsd').absolute())
parser = etree.XMLParser(remove_blank_text=True)

et = etree.parse(path_xsd, parser)
root = et.getroot()
all_el = list(root.iterfind('*//xs:element', namespaces=namespaces))

# %%
def get_meaningful_parent(el):
    parent = el.getparent()
    while parent.tag !=f'{xs}element' or parent.attrib.get('name') in ['donnee_intermediaire','donnee_entree']:
        parent = parent.getparent()
        if parent is None:
            break

    return parent

# %%
types_dict = dict()

for el in all_el:
    if el.find('xs:simpleType', namespaces=namespaces) is not None:
        simple_type_custom = el.find('xs:simpleType', namespaces=namespaces)
        
        name = el.attrib['name']
        type_name = name +'_type'
        if any(name.startswith(el) for el  in ["tv",'enum','reference']):
            
            pass
        
        else:
            parent = get_meaningful_parent(el)
            if parent is not None:
                type_name = parent.attrib['name']+'_'+name+'_type'
                print(type_name)
        if type_name not in types_dict:
            
            
            simple_type = copy.copy(el.find('xs:simpleType', namespaces=namespaces))
            simple_type.attrib['name']=type_name

            annotation = copy.copy(el.find('xs:annotation', namespaces=namespaces))
            
            appinfo = annotation.find('xs:appinfo',namespaces=namespaces)
            if appinfo is not None:
                if annotation.find('xs:appinfo',namespaces=namespaces).text is None:
                    annotation.remove(annotation.find('xs:appinfo',namespaces=namespaces))
                else:

                    if 'source' in appinfo.attrib:
                        del appinfo.attrib['source']
            else:
                pass
            
            documentation = annotation.find('xs:documentation',namespaces=namespaces)
            documentation.text = f"type de la propriété : {el.attrib['name']}"
            
            simple_type.insert(0,annotation)
            
            types_dict[type_name]=simple_type
            root.append(simple_type)
        el.remove(simple_type_custom)
        el.attrib['type']=type_name
# Out:
# caracteristique_generale_annee_construction_type
# caracteristique_generale_surface_habitable_logement_type
# caracteristique_generale_nombre_niveau_immeuble_type
# caracteristique_generale_nombre_niveau_logement_type
# caracteristique_generale_hsp_type
# caracteristique_generale_surface_habitable_immeuble_type
# caracteristique_generale_surface_tertiaire_immeuble_type
# caracteristique_generale_nombre_appartement_type
# plancher_bas_surface_aiu_type
# plancher_bas_surface_aue_type
# plancher_bas_surface_paroi_opaque_type
# plancher_bas_upb0_saisi_type
# plancher_bas_upb_saisi_type
# plancher_bas_resistance_isolation_type
# plancher_bas_epaisseur_isolation_type
# plancher_bas_perimetre_ue_type
# plancher_bas_surface_ue_type
# plancher_bas_ue_type
# plancher_bas_b_type
# plancher_bas_upb_type
# plancher_bas_upb_final_type
# plancher_bas_upb0_type
# plancher_haut_surface_aiu_type
# plancher_haut_surface_aue_type
# plancher_haut_surface_paroi_opaque_type
# plancher_haut_uph0_saisi_type
# plancher_haut_uph_saisi_type
# plancher_haut_resistance_isolation_type
# plancher_haut_epaisseur_isolation_type
# plancher_haut_b_type
# plancher_haut_uph_type
# plancher_haut_uph0_type
# baie_vitree_surface_aiu_type
# baie_vitree_surface_aue_type
# baie_vitree_surface_totale_baie_type
# baie_vitree_nb_baie_type
# baie_vitree_epaisseur_lame_type
# baie_vitree_ug_saisi_type
# baie_vitree_uw_saisi_type
# baie_vitree_uw_1_type
# baie_vitree_sw_1_type
# baie_vitree_uw_2_type
# baie_vitree_sw_2_type
# baie_vitree_ujn_saisi_type
# baie_vitree_largeur_dormant_type
# baie_vitree_sw_saisi_type
# baie_vitree_b_type
# baie_vitree_ug_type
# baie_vitree_uw_type
# baie_vitree_ujn_type
# baie_vitree_u_menuiserie_type
# baie_vitree_sw_type
# baie_vitree_fe1_type
# baie_vitree_fe2_type
# porte_surface_aiu_type
# porte_surface_aue_type
# porte_surface_porte_type
# porte_uporte_saisi_type
# porte_nb_porte_type
# porte_largeur_dormant_type
# porte_uporte_type
# porte_b_type
# baie_ets_surface_totale_baie_type
# baie_ets_nb_baie_type
# ets_coef_transparence_ets_type
# ets_bver_type
# pont_thermique_pourcentage_valeur_pont_thermique_type
# pont_thermique_l_type
# pont_thermique_k_saisi_type
# pont_thermique_k_type
# ventilation_surface_ventile_type
# ventilation_q4pa_conv_saisi_type
# ventilation_ref_produit_ventilation_type
# ventilation_cle_repartition_ventilation_type
# ventilation_pvent_moy_type
# ventilation_q4pa_conv_type
# ventilation_conso_auxiliaire_ventilation_type
# ventilation_hperm_type
# ventilation_hvent_type
# climatisation_surface_clim_type
# climatisation_nombre_logement_echantillon_type
# climatisation_cle_repartition_clim_type
# climatisation_ref_produit_fr_type
# climatisation_eer_type
# climatisation_besoin_fr_type
# climatisation_conso_fr_type
# climatisation_conso_fr_depensier_type
# production_elec_enr_taux_autoproduction_type
# production_elec_enr_production_pv_type
# production_elec_enr_conso_elec_ac_type
# panneaux_pv_surface_totale_capteurs_type
# panneaux_pv_ratio_virtualisation_type
# panneaux_pv_nombre_module_type
# installation_ecs_ratio_virtualisation_type
# installation_ecs_cle_repartition_ecs_type
# installation_ecs_surface_habitable_type
# installation_ecs_nombre_logement_type
# installation_ecs_nombre_niveau_installation_ecs_type
# installation_ecs_fecs_saisi_type
# installation_ecs_rendement_distribution_type
# installation_ecs_besoin_ecs_type
# installation_ecs_besoin_ecs_depensier_type
# installation_ecs_fecs_type
# installation_ecs_production_ecs_solaire_type
# installation_ecs_conso_ecs_type
# installation_ecs_conso_ecs_depensier_type
# generateur_ecs_ref_produit_generateur_ecs_type
# generateur_ecs_identifiant_reseau_chaleur_type
# generateur_ecs_volume_stockage_type
# generateur_ecs_pn_type
# generateur_ecs_qp0_type
# generateur_ecs_pveilleuse_type
# generateur_ecs_rpn_type
# generateur_ecs_cop_type
# generateur_ecs_ratio_besoin_ecs_type
# generateur_ecs_rendement_generation_type
# generateur_ecs_rendement_generation_stockage_type
# generateur_ecs_conso_ecs_type
# generateur_ecs_conso_ecs_depensier_type
# generateur_ecs_rendement_stockage_type
# installation_chauffage_surface_chauffee_type
# installation_chauffage_nombre_logement_echantillon_type
# installation_chauffage_nombre_niveau_installation_ch_type
# installation_chauffage_ratio_virtualisation_type
# installation_chauffage_coef_ifc_type
# installation_chauffage_cle_repartition_ch_type
# installation_chauffage_fch_saisi_type
# installation_chauffage_besoin_ch_type
# installation_chauffage_besoin_ch_depensier_type
# installation_chauffage_production_ch_solaire_type
# installation_chauffage_fch_type
# installation_chauffage_conso_ch_type
# installation_chauffage_conso_ch_depensier_type
# emetteur_chauffage_surface_chauffee_type
# emetteur_chauffage_i0_type
# emetteur_chauffage_rendement_emission_type
# emetteur_chauffage_rendement_distribution_type
# emetteur_chauffage_rendement_regulation_type
# generateur_chauffage_ref_produit_generateur_ch_type
# generateur_chauffage_identifiant_reseau_chaleur_type
# generateur_chauffage_n_radiateurs_gaz_type
# generateur_chauffage_priorite_generateur_cascade_type
# generateur_chauffage_scop_type
# generateur_chauffage_pn_type
# generateur_chauffage_qp0_type
# generateur_chauffage_pveilleuse_type
# generateur_chauffage_temp_fonc_30_type
# generateur_chauffage_temp_fonc_100_type
# generateur_chauffage_rpn_type
# generateur_chauffage_rpint_type
# generateur_chauffage_rendement_generation_type
# generateur_chauffage_conso_ch_type
# generateur_chauffage_conso_ch_depensier_type
# deperdition_hvent_type
# deperdition_hperm_type
# deperdition_deperdition_renouvellement_air_type
# deperdition_deperdition_mur_type
# deperdition_deperdition_plancher_bas_type
# deperdition_deperdition_plancher_haut_type
# deperdition_deperdition_baie_vitree_type
# deperdition_deperdition_porte_type
# deperdition_deperdition_pont_thermique_type
# deperdition_deperdition_enveloppe_type
# apport_et_besoin_surface_sud_equivalente_type
# apport_et_besoin_apport_solaire_fr_type
# apport_et_besoin_apport_interne_fr_type
# apport_et_besoin_apport_solaire_ch_type
# apport_et_besoin_apport_interne_ch_type
# apport_et_besoin_fraction_apport_gratuit_ch_type
# apport_et_besoin_fraction_apport_gratuit_depensier_ch_type
# apport_et_besoin_pertes_distribution_ecs_recup_type
# apport_et_besoin_pertes_distribution_ecs_recup_depensier_type
# apport_et_besoin_pertes_stockage_ecs_recup_type
# apport_et_besoin_pertes_generateur_ch_recup_type
# apport_et_besoin_pertes_generateur_ch_recup_depensier_type
# apport_et_besoin_nadeq_type
# apport_et_besoin_v40_ecs_journalier_type
# apport_et_besoin_v40_ecs_journalier_depensier_type
# apport_et_besoin_besoin_ch_type
# apport_et_besoin_besoin_ch_depensier_type
# apport_et_besoin_besoin_ecs_type
# apport_et_besoin_besoin_ecs_depensier_type
# apport_et_besoin_besoin_fr_type
# apport_et_besoin_besoin_fr_depensier_type
# ef_conso_conso_ch_type
# ef_conso_conso_ch_depensier_type
# ef_conso_conso_ecs_type
# ef_conso_conso_ecs_depensier_type
# ef_conso_conso_eclairage_type
# ef_conso_conso_auxiliaire_generation_ch_type
# ef_conso_conso_auxiliaire_generation_ch_depensier_type
# ef_conso_conso_auxiliaire_distribution_ch_type
# ef_conso_conso_auxiliaire_generation_ecs_type
# ef_conso_conso_auxiliaire_generation_ecs_depensier_type
# ef_conso_conso_auxiliaire_distribution_ecs_type
# ef_conso_conso_auxiliaire_distribution_fr_type
# ef_conso_conso_auxiliaire_ventilation_type
# ef_conso_conso_totale_auxiliaire_type
# ef_conso_conso_fr_type
# ef_conso_conso_fr_depensier_type
# ef_conso_conso_5_usages_type
# ef_conso_conso_5_usages_m2_type
# ep_conso_ep_conso_ch_type
# ep_conso_ep_conso_ch_depensier_type
# ep_conso_ep_conso_ecs_type
# ep_conso_ep_conso_ecs_depensier_type
# ep_conso_ep_conso_eclairage_type
# ep_conso_ep_conso_auxiliaire_generation_ch_type
# ep_conso_ep_conso_auxiliaire_generation_ch_depensier_type
# ep_conso_ep_conso_auxiliaire_distribution_ch_type
# ep_conso_ep_conso_auxiliaire_generation_ecs_type
# ep_conso_ep_conso_auxiliaire_generation_ecs_depensier_type
# ep_conso_ep_conso_auxiliaire_distribution_ecs_type
# ep_conso_ep_conso_auxiliaire_distribution_fr_type
# ep_conso_ep_conso_auxiliaire_ventilation_type
# ep_conso_ep_conso_totale_auxiliaire_type
# ep_conso_ep_conso_fr_type
# ep_conso_ep_conso_fr_depensier_type
# ep_conso_ep_conso_5_usages_type
# ep_conso_ep_conso_5_usages_m2_type
# emission_ges_emission_ges_ch_type
# emission_ges_emission_ges_ch_depensier_type
# emission_ges_emission_ges_ecs_type
# emission_ges_emission_ges_ecs_depensier_type
# emission_ges_emission_ges_eclairage_type
# emission_ges_emission_ges_auxiliaire_generation_ch_type
# emission_ges_emission_ges_auxiliaire_generation_ch_depensier_type
# emission_ges_emission_ges_auxiliaire_distribution_ch_type
# emission_ges_emission_ges_auxiliaire_generation_ecs_type
# emission_ges_emission_ges_auxiliaire_generation_ecs_depensier_type
# emission_ges_emission_ges_auxiliaire_distribution_ecs_type
# emission_ges_emission_ges_auxiliaire_distribution_fr_type
# emission_ges_emission_ges_auxiliaire_ventilation_type
# emission_ges_emission_ges_totale_auxiliaire_type
# emission_ges_emission_ges_fr_type
# emission_ges_emission_ges_fr_depensier_type
# emission_ges_emission_ges_5_usages_type
# emission_ges_emission_ges_5_usages_m2_type
# cout_cout_ch_type
# cout_cout_ch_depensier_type
# cout_cout_ecs_type
# cout_cout_ecs_depensier_type
# cout_cout_eclairage_type
# cout_cout_auxiliaire_generation_ch_type
# cout_cout_auxiliaire_generation_ch_depensier_type
# cout_cout_auxiliaire_distribution_ch_type
# cout_cout_auxiliaire_generation_ecs_type
# cout_cout_auxiliaire_generation_ecs_depensier_type
# cout_cout_auxiliaire_distribution_ecs_type
# cout_cout_auxiliaire_distribution_fr_type
# cout_cout_auxiliaire_ventilation_type
# cout_cout_total_auxiliaire_type
# cout_cout_fr_type
# cout_cout_fr_depensier_type
# cout_cout_5_usages_type
# production_electricite_production_pv_type
# production_electricite_conso_elec_ac_type
# production_electricite_conso_elec_ac_ch_type
# production_electricite_conso_elec_ac_ecs_type
# production_electricite_conso_elec_ac_fr_type
# production_electricite_conso_elec_ac_eclairage_type
# production_electricite_conso_elec_ac_auxiliaire_type
# production_electricite_conso_elec_ac_autre_usage_type
# sortie_par_energie_conso_ch_type
# sortie_par_energie_conso_ecs_type
# sortie_par_energie_conso_5_usages_type
# sortie_par_energie_emission_ges_ch_type
# sortie_par_energie_emission_ges_ecs_type
# sortie_par_energie_emission_ges_5_usages_type
# sortie_par_energie_cout_ch_type
# sortie_par_energie_cout_ecs_type
# sortie_par_energie_cout_5_usages_type
# qualite_isolation_ubat_type
# caracteristique_generale_surface_utile_type
# caracteristique_generale_shon_type
# caracteristique_generale_nombre_occupant_type
# caracteristique_generale_annee_construction_type
# consommation_annee_consommation_type
# repartition_chauffage_surface_baie_nord_type
# repartition_chauffage_surface_baie_sud_type
# repartition_chauffage_surface_baie_est_ouest_type
# repartition_chauffage_surface_paroi_verticale_ext_type
# repartition_chauffage_surface_plancher_haut_type
# repartition_chauffage_surface_plancher_bas_type
# repartition_chauffage_coef_ifc_type
# repartition_chauffage_deperdition_totale_logement_type
# repartition_chauffage_deperdition_totale_batiment_type
# repartition_chauffage_cle_repartition_ch_type
# repartition_ecs_besoin_ecs_batiment_type
# repartition_ecs_besoin_ecs_logement_type
# repartition_ecs_cle_repartition_ecs_type
# caracteristique_generale_annee_construction_type
# caracteristique_generale_surface_habitable_logement_type
# caracteristique_generale_nombre_niveau_immeuble_type
# caracteristique_generale_nombre_niveau_logement_type
# caracteristique_generale_hsp_type
# caracteristique_generale_surface_habitable_immeuble_type
# caracteristique_generale_surface_tertiaire_immeuble_type
# caracteristique_generale_nombre_appartement_type
# plancher_bas_surface_aiu_type
# plancher_bas_surface_aue_type
# plancher_bas_surface_paroi_opaque_type
# plancher_bas_resistance_isolation_type
# plancher_bas_epaisseur_isolation_type
# plancher_bas_b_type
# plancher_bas_upb_final_type
# plancher_bas_upb0_type
# plancher_haut_surface_aiu_type
# plancher_haut_surface_aue_type
# plancher_haut_surface_paroi_opaque_type
# plancher_haut_resistance_isolation_type
# plancher_haut_epaisseur_isolation_type
# plancher_haut_b_type
# plancher_haut_uph_type
# plancher_haut_uph0_type
# baie_vitree_surface_aiu_type
# baie_vitree_surface_aue_type
# baie_vitree_surface_totale_baie_type
# baie_vitree_nb_baie_type
# baie_vitree_epaisseur_lame_type
# baie_vitree_b_type
# baie_vitree_ug_type
# baie_vitree_uw_type
# baie_vitree_ujn_type
# baie_vitree_u_menuiserie_type
# baie_vitree_sw_type
# porte_surface_aiu_type
# porte_surface_aue_type
# porte_surface_porte_type
# porte_nb_porte_type
# porte_largeur_dormant_type
# porte_uporte_type
# porte_b_type
# pont_thermique_l_type
# pont_thermique_k_type
# ventilation_surface_ventile_type
# ventilation_ref_produit_ventilation_type
# ventilation_pvent_moy_type
# ventilation_q4pa_conv_type
# ventilation_conso_auxiliaire_ventilation_type
# ventilation_hperm_type
# ventilation_hvent_type
# climatisation_surface_clim_type
# climatisation_ref_produit_fr_type
# climatisation_eer_type
# climatisation_besoin_fr_type
# climatisation_conso_fr_type
# production_elec_enr_taux_autoproduction_type
# production_elec_enr_production_pv_type
# production_elec_enr_conso_elec_ac_type
# panneaux_pv_surface_totale_capteurs_type
# panneaux_pv_nombre_module_type
# installation_ecs_surface_habitable_type
# installation_ecs_nombre_logement_type
# installation_ecs_besoin_ecs_type
# installation_ecs_production_ecs_solaire_type
# installation_ecs_conso_ecs_type
# generateur_ecs_ref_produit_generateur_ecs_type
# generateur_ecs_volume_stockage_type
# generateur_ecs_identifiant_reseau_chaleur_type
# generateur_ecs_pn_type
# generateur_ecs_qp0_type
# generateur_ecs_pveilleuse_type
# generateur_ecs_rpn_type
# generateur_ecs_cop_type
# generateur_ecs_ratio_besoin_ecs_type
# generateur_ecs_conso_ecs_type
# installation_chauffage_surface_chauffee_type
# installation_chauffage_besoin_ch_type
# installation_chauffage_conso_ch_type
# emetteur_chauffage_surface_chauffee_type
# generateur_chauffage_ref_produit_generateur_ch_type
# generateur_chauffage_identifiant_reseau_chaleur_type
# generateur_chauffage_n_radiateurs_gaz_type
# generateur_chauffage_scop_type
# generateur_chauffage_pn_type
# generateur_chauffage_qp0_type
# generateur_chauffage_pveilleuse_type
# generateur_chauffage_temp_fonc_30_type
# generateur_chauffage_temp_fonc_100_type
# generateur_chauffage_rpn_type
# generateur_chauffage_rpint_type
# generateur_chauffage_conso_ch_type
# deperdition_hvent_type
# deperdition_hperm_type
# deperdition_deperdition_renouvellement_air_type
# deperdition_deperdition_mur_type
# deperdition_deperdition_plancher_bas_type
# deperdition_deperdition_plancher_haut_type
# deperdition_deperdition_baie_vitree_type
# deperdition_deperdition_porte_type
# deperdition_deperdition_pont_thermique_type
# deperdition_deperdition_enveloppe_type
# apport_et_besoin_besoin_ch_type
# apport_et_besoin_besoin_ecs_type
# apport_et_besoin_besoin_fr_type
# ef_conso_conso_ch_type
# ef_conso_conso_ch_depensier_type
# ef_conso_conso_ecs_type
# ef_conso_conso_ecs_depensier_type
# ef_conso_conso_eclairage_type
# ef_conso_conso_auxiliaire_ventilation_type
# ef_conso_conso_totale_auxiliaire_type
# ef_conso_conso_fr_type
# ef_conso_conso_fr_depensier_type
# ef_conso_conso_5_usages_type
# ef_conso_conso_5_usages_m2_type
# ep_conso_ep_conso_ch_type
# ep_conso_ep_conso_ch_depensier_type
# ep_conso_ep_conso_ecs_type
# ep_conso_ep_conso_ecs_depensier_type
# ep_conso_ep_conso_eclairage_type
# ep_conso_ep_conso_auxiliaire_ventilation_type
# ep_conso_ep_conso_totale_auxiliaire_type
# ep_conso_ep_conso_fr_type
# ep_conso_ep_conso_fr_depensier_type
# ep_conso_ep_conso_5_usages_type
# ep_conso_ep_conso_5_usages_m2_type
# emission_ges_emission_ges_ch_type
# emission_ges_emission_ges_ch_depensier_type
# emission_ges_emission_ges_ecs_type
# emission_ges_emission_ges_ecs_depensier_type
# emission_ges_emission_ges_eclairage_type
# emission_ges_emission_ges_auxiliaire_ventilation_type
# emission_ges_emission_ges_totale_auxiliaire_type
# emission_ges_emission_ges_fr_type
# emission_ges_emission_ges_fr_depensier_type
# emission_ges_emission_ges_5_usages_type
# emission_ges_emission_ges_5_usages_m2_type
# cout_cout_ch_type
# cout_cout_ch_depensier_type
# cout_cout_ecs_type
# cout_cout_ecs_depensier_type
# cout_cout_eclairage_type
# cout_cout_auxiliaire_ventilation_type
# cout_cout_total_auxiliaire_type
# cout_cout_fr_type
# cout_cout_fr_depensier_type
# cout_cout_5_usages_type
# production_electricite_production_pv_type
# sortie_par_energie_conso_ch_type
# sortie_par_energie_conso_ecs_type
# sortie_par_energie_conso_5_usages_type
# sortie_par_energie_emission_ges_ch_type
# sortie_par_energie_emission_ges_ecs_type
# sortie_par_energie_emission_ges_5_usages_type
# sortie_par_energie_cout_ch_type
# sortie_par_energie_cout_ecs_type
# sortie_par_energie_cout_5_usages_type
# qualite_isolation_ubat_type
# pack_travaux_conso_5_usages_apres_travaux_type
# pack_travaux_emission_ges_5_usages_apres_travaux_type
# pack_travaux_cout_pack_travaux_min_type
# pack_travaux_cout_pack_travaux_max_type
# travaux_avertissement_travaux_type
# travaux_performance_recommande_type
# administratif_dpe_a_remplacer_type
# administratif_dpe_immeuble_associe_type
# administratif_date_visite_diagnostiqueur_type
# administratif_nom_proprietaire_type
# administratif_siren_proprietaire_type
# administratif_nom_proprietaire_installation_commune_type
# administratif_date_etablissement_dpe_type
# diagnostiqueur_usr_logiciel_id_type
# diagnostiqueur_version_logiciel_type
# diagnostiqueur_version_moteur_calcul_type
# diagnostiqueur_nom_diagnostiqueur_type
# diagnostiqueur_prenom_diagnostiqueur_type
# diagnostiqueur_mail_diagnostiqueur_type
# diagnostiqueur_telephone_diagnostiqueur_type
# diagnostiqueur_adresse_diagnostiqueur_type
# diagnostiqueur_entreprise_diagnostiqueur_type
# diagnostiqueur_numero_certification_diagnostiqueur_type
# diagnostiqueur_organisme_certificateur_type
# geolocalisation_rpls_log_id_type
# geolocalisation_rpls_org_id_type
# geolocalisation_immatriculation_copropriete_type
# caracteristique_generale_annee_construction_type
# caracteristique_generale_surface_habitable_logement_type
# caracteristique_generale_nombre_niveau_immeuble_type
# caracteristique_generale_nombre_niveau_logement_type
# caracteristique_generale_hsp_type
# caracteristique_generale_surface_habitable_immeuble_type
# caracteristique_generale_surface_tertiaire_immeuble_type
# caracteristique_generale_nombre_appartement_type
# mur_surface_aiu_type
# mur_surface_aue_type
# mur_surface_paroi_totale_type
# mur_surface_paroi_opaque_type
# mur_umur0_saisi_type
# mur_epaisseur_structure_type
# mur_umur_saisi_type
# mur_resistance_isolation_type
# mur_epaisseur_isolation_type
# mur_b_type
# mur_umur_type
# mur_umur0_type
# plancher_bas_surface_aiu_type
# plancher_bas_surface_aue_type
# plancher_bas_surface_paroi_opaque_type
# plancher_bas_upb0_saisi_type
# plancher_bas_upb_saisi_type
# plancher_bas_resistance_isolation_type
# plancher_bas_epaisseur_isolation_type
# plancher_bas_perimetre_ue_type
# plancher_bas_surface_ue_type
# plancher_bas_ue_type
# plancher_bas_b_type
# plancher_bas_upb_type
# plancher_bas_upb_final_type
# plancher_bas_upb0_type
# plancher_haut_surface_aiu_type
# plancher_haut_surface_aue_type
# plancher_haut_surface_paroi_opaque_type
# plancher_haut_uph0_saisi_type
# plancher_haut_uph_saisi_type
# plancher_haut_resistance_isolation_type
# plancher_haut_epaisseur_isolation_type
# plancher_haut_b_type
# plancher_haut_uph_type
# plancher_haut_uph0_type
# baie_vitree_surface_aiu_type
# baie_vitree_surface_aue_type
# baie_vitree_surface_totale_baie_type
# baie_vitree_nb_baie_type
# baie_vitree_epaisseur_lame_type
# baie_vitree_ug_saisi_type
# baie_vitree_uw_saisi_type
# baie_vitree_uw_1_type
# baie_vitree_sw_1_type
# baie_vitree_uw_2_type
# baie_vitree_sw_2_type
# baie_vitree_ujn_saisi_type
# baie_vitree_largeur_dormant_type
# baie_vitree_sw_saisi_type
# baie_vitree_b_type
# baie_vitree_ug_type
# baie_vitree_uw_type
# baie_vitree_ujn_type
# baie_vitree_u_menuiserie_type
# baie_vitree_sw_type
# baie_vitree_fe1_type
# baie_vitree_fe2_type
# porte_surface_aiu_type
# porte_surface_aue_type
# porte_surface_porte_type
# porte_uporte_saisi_type
# porte_nb_porte_type
# porte_largeur_dormant_type
# porte_uporte_type
# porte_b_type
# baie_ets_surface_totale_baie_type
# baie_ets_nb_baie_type
# ets_coef_transparence_ets_type
# ets_bver_type
# pont_thermique_pourcentage_valeur_pont_thermique_type
# pont_thermique_l_type
# pont_thermique_k_saisi_type
# pont_thermique_k_type
# ventilation_surface_ventile_type
# ventilation_q4pa_conv_saisi_type
# ventilation_ref_produit_ventilation_type
# ventilation_cle_repartition_ventilation_type
# ventilation_pvent_moy_type
# ventilation_q4pa_conv_type
# ventilation_conso_auxiliaire_ventilation_type
# ventilation_hperm_type
# ventilation_hvent_type
# climatisation_surface_clim_type
# climatisation_nombre_logement_echantillon_type
# climatisation_cle_repartition_clim_type
# climatisation_ref_produit_fr_type
# climatisation_eer_type
# climatisation_besoin_fr_type
# climatisation_conso_fr_type
# climatisation_conso_fr_depensier_type
# production_elec_enr_taux_autoproduction_type
# production_elec_enr_production_pv_type
# production_elec_enr_conso_elec_ac_type
# panneaux_pv_surface_totale_capteurs_type
# panneaux_pv_ratio_virtualisation_type
# panneaux_pv_nombre_module_type
# installation_ecs_ratio_virtualisation_type
# installation_ecs_cle_repartition_ecs_type
# installation_ecs_surface_habitable_type
# installation_ecs_nombre_logement_type
# installation_ecs_nombre_niveau_installation_ecs_type
# installation_ecs_fecs_saisi_type
# installation_ecs_rendement_distribution_type
# installation_ecs_besoin_ecs_type
# installation_ecs_besoin_ecs_depensier_type
# installation_ecs_fecs_type
# installation_ecs_production_ecs_solaire_type
# installation_ecs_conso_ecs_type
# installation_ecs_conso_ecs_depensier_type
# generateur_ecs_ref_produit_generateur_ecs_type
# generateur_ecs_identifiant_reseau_chaleur_type
# generateur_ecs_volume_stockage_type
# generateur_ecs_pn_type
# generateur_ecs_qp0_type
# generateur_ecs_pveilleuse_type
# generateur_ecs_rpn_type
# generateur_ecs_cop_type
# generateur_ecs_ratio_besoin_ecs_type
# generateur_ecs_rendement_generation_type
# generateur_ecs_rendement_generation_stockage_type
# generateur_ecs_conso_ecs_type
# generateur_ecs_conso_ecs_depensier_type
# generateur_ecs_rendement_stockage_type
# installation_chauffage_surface_chauffee_type
# installation_chauffage_nombre_logement_echantillon_type
# installation_chauffage_nombre_niveau_installation_ch_type
# installation_chauffage_ratio_virtualisation_type
# installation_chauffage_coef_ifc_type
# installation_chauffage_cle_repartition_ch_type
# installation_chauffage_fch_saisi_type
# installation_chauffage_besoin_ch_type
# installation_chauffage_besoin_ch_depensier_type
# installation_chauffage_production_ch_solaire_type
# installation_chauffage_fch_type
# installation_chauffage_conso_ch_type
# installation_chauffage_conso_ch_depensier_type
# emetteur_chauffage_surface_chauffee_type
# emetteur_chauffage_i0_type
# emetteur_chauffage_rendement_emission_type
# emetteur_chauffage_rendement_distribution_type
# emetteur_chauffage_rendement_regulation_type
# generateur_chauffage_ref_produit_generateur_ch_type
# generateur_chauffage_identifiant_reseau_chaleur_type
# generateur_chauffage_n_radiateurs_gaz_type
# generateur_chauffage_priorite_generateur_cascade_type
# generateur_chauffage_scop_type
# generateur_chauffage_pn_type
# generateur_chauffage_qp0_type
# generateur_chauffage_pveilleuse_type
# generateur_chauffage_temp_fonc_30_type
# generateur_chauffage_temp_fonc_100_type
# generateur_chauffage_rpn_type
# generateur_chauffage_rpint_type
# generateur_chauffage_rendement_generation_type
# generateur_chauffage_conso_ch_type
# generateur_chauffage_conso_ch_depensier_type
# deperdition_hvent_type
# deperdition_hperm_type
# deperdition_deperdition_renouvellement_air_type
# deperdition_deperdition_mur_type
# deperdition_deperdition_plancher_bas_type
# deperdition_deperdition_plancher_haut_type
# deperdition_deperdition_baie_vitree_type
# deperdition_deperdition_porte_type
# deperdition_deperdition_pont_thermique_type
# deperdition_deperdition_enveloppe_type
# apport_et_besoin_surface_sud_equivalente_type
# apport_et_besoin_apport_solaire_fr_type
# apport_et_besoin_apport_interne_fr_type
# apport_et_besoin_apport_solaire_ch_type
# apport_et_besoin_apport_interne_ch_type
# apport_et_besoin_fraction_apport_gratuit_ch_type
# apport_et_besoin_fraction_apport_gratuit_depensier_ch_type
# apport_et_besoin_pertes_distribution_ecs_recup_type
# apport_et_besoin_pertes_distribution_ecs_recup_depensier_type
# apport_et_besoin_pertes_stockage_ecs_recup_type
# apport_et_besoin_pertes_generateur_ch_recup_type
# apport_et_besoin_pertes_generateur_ch_recup_depensier_type
# apport_et_besoin_nadeq_type
# apport_et_besoin_v40_ecs_journalier_type
# apport_et_besoin_v40_ecs_journalier_depensier_type
# apport_et_besoin_besoin_ch_type
# apport_et_besoin_besoin_ch_depensier_type
# apport_et_besoin_besoin_ecs_type
# apport_et_besoin_besoin_ecs_depensier_type
# apport_et_besoin_besoin_fr_type
# apport_et_besoin_besoin_fr_depensier_type
# ef_conso_conso_ch_type
# ef_conso_conso_ch_depensier_type
# ef_conso_conso_ecs_type
# ef_conso_conso_ecs_depensier_type
# ef_conso_conso_eclairage_type
# ef_conso_conso_auxiliaire_generation_ch_type
# ef_conso_conso_auxiliaire_generation_ch_depensier_type
# ef_conso_conso_auxiliaire_distribution_ch_type
# ef_conso_conso_auxiliaire_generation_ecs_type
# ef_conso_conso_auxiliaire_generation_ecs_depensier_type
# ef_conso_conso_auxiliaire_distribution_ecs_type
# ef_conso_conso_auxiliaire_distribution_fr_type
# ef_conso_conso_auxiliaire_ventilation_type
# ef_conso_conso_totale_auxiliaire_type
# ef_conso_conso_fr_type
# ef_conso_conso_fr_depensier_type
# ef_conso_conso_5_usages_type
# ef_conso_conso_5_usages_m2_type
# ep_conso_ep_conso_ch_type
# ep_conso_ep_conso_ch_depensier_type
# ep_conso_ep_conso_ecs_type
# ep_conso_ep_conso_ecs_depensier_type
# ep_conso_ep_conso_eclairage_type
# ep_conso_ep_conso_auxiliaire_generation_ch_type
# ep_conso_ep_conso_auxiliaire_generation_ch_depensier_type
# ep_conso_ep_conso_auxiliaire_distribution_ch_type
# ep_conso_ep_conso_auxiliaire_generation_ecs_type
# ep_conso_ep_conso_auxiliaire_generation_ecs_depensier_type
# ep_conso_ep_conso_auxiliaire_distribution_ecs_type
# ep_conso_ep_conso_auxiliaire_distribution_fr_type
# ep_conso_ep_conso_auxiliaire_ventilation_type
# ep_conso_ep_conso_totale_auxiliaire_type
# ep_conso_ep_conso_fr_type
# ep_conso_ep_conso_fr_depensier_type
# ep_conso_ep_conso_5_usages_type
# ep_conso_ep_conso_5_usages_m2_type
# emission_ges_emission_ges_ch_type
# emission_ges_emission_ges_ch_depensier_type
# emission_ges_emission_ges_ecs_type
# emission_ges_emission_ges_ecs_depensier_type
# emission_ges_emission_ges_eclairage_type
# emission_ges_emission_ges_auxiliaire_generation_ch_type
# emission_ges_emission_ges_auxiliaire_generation_ch_depensier_type
# emission_ges_emission_ges_auxiliaire_distribution_ch_type
# emission_ges_emission_ges_auxiliaire_generation_ecs_type
# emission_ges_emission_ges_auxiliaire_generation_ecs_depensier_type
# emission_ges_emission_ges_auxiliaire_distribution_ecs_type
# emission_ges_emission_ges_auxiliaire_distribution_fr_type
# emission_ges_emission_ges_auxiliaire_ventilation_type
# emission_ges_emission_ges_totale_auxiliaire_type
# emission_ges_emission_ges_fr_type
# emission_ges_emission_ges_fr_depensier_type
# emission_ges_emission_ges_5_usages_type
# emission_ges_emission_ges_5_usages_m2_type
# cout_cout_ch_type
# cout_cout_ch_depensier_type
# cout_cout_ecs_type
# cout_cout_ecs_depensier_type
# cout_cout_eclairage_type
# cout_cout_auxiliaire_generation_ch_type
# cout_cout_auxiliaire_generation_ch_depensier_type
# cout_cout_auxiliaire_distribution_ch_type
# cout_cout_auxiliaire_generation_ecs_type
# cout_cout_auxiliaire_generation_ecs_depensier_type
# cout_cout_auxiliaire_distribution_ecs_type
# cout_cout_auxiliaire_distribution_fr_type
# cout_cout_auxiliaire_ventilation_type
# cout_cout_total_auxiliaire_type
# cout_cout_fr_type
# cout_cout_fr_depensier_type
# cout_cout_5_usages_type
# production_electricite_production_pv_type
# production_electricite_conso_elec_ac_type
# production_electricite_conso_elec_ac_ch_type
# production_electricite_conso_elec_ac_ecs_type
# production_electricite_conso_elec_ac_fr_type
# production_electricite_conso_elec_ac_eclairage_type
# production_electricite_conso_elec_ac_auxiliaire_type
# production_electricite_conso_elec_ac_autre_usage_type
# sortie_par_energie_conso_ch_type
# sortie_par_energie_conso_ecs_type
# sortie_par_energie_conso_5_usages_type
# sortie_par_energie_emission_ges_ch_type
# sortie_par_energie_emission_ges_ecs_type
# sortie_par_energie_emission_ges_5_usages_type
# sortie_par_energie_cout_ch_type
# sortie_par_energie_cout_ecs_type
# sortie_par_energie_cout_5_usages_type
# qualite_isolation_ubat_type
# etape_travaux_ep_conso_5_usages_m2_type
# etape_travaux_ep_conso_5_usages_m2_sans_ac_type
# etape_travaux_ef_conso_5_usages_m2_type
# etape_travaux_ef_conso_5_usages_m2_sans_ac_type
# etape_travaux_emission_ges_5_usages_m2_type
# etape_travaux_cout_type
# etape_travaux_ep_conso_5_usages_m2_gain_type
# etape_travaux_ep_conso_5_usages_m2_gain_relatif_type
# etape_travaux_ef_conso_5_usages_m2_gain_type
# etape_travaux_ef_conso_5_usages_m2_gain_relatif_type
# etape_travaux_emission_ges_5_usages_m2_gain_type
# etape_travaux_emission_ges_5_usages_m2_gain_relatif_type
# etape_travaux_facture_gain_min_type
# etape_travaux_facture_gain_max_type
# etape_travaux_cout_cumule_type
# etape_travaux_ep_conso_5_usages_m2_gain_cumule_type
# etape_travaux_ep_conso_5_usages_m2_gain_cumule_relatif_type
# etape_travaux_ef_conso_5_usages_m2_gain_cumule_type
# etape_travaux_ef_conso_5_usages_m2_gain_cumule_relatif_type
# etape_travaux_emission_ges_5_usages_m2_gain_cumule_type
# etape_travaux_emission_ges_5_usages_m2_gain_cumule_relatif_type
# etape_travaux_facture_gain_cumule_min_type
# etape_travaux_facture_gain_cumule_max_type
# travaux_cout_type
# administratif_audit_numero_dpe_type
# administratif_audit_date_visite_auditeur_type
# administratif_audit_nom_proprietaire_type
# administratif_audit_siren_proprietaire_type
# administratif_audit_nom_proprietaire_installation_commune_type
# administratif_audit_date_etablissement_audit_type
# auditeur_usr_logiciel_id_type
# auditeur_version_logiciel_type
# auditeur_version_moteur_calcul_type
# auditeur_nom_auditeur_type
# auditeur_prenom_auditeur_type
# auditeur_mail_auditeur_type
# auditeur_telephone_auditeur_type
# auditeur_adresse_auditeur_type
# auditeur_entreprise_auditeur_type
# auditeur_numero_certification_auditeur_type
# auditeur_organisme_certificateur_type
# geolocalisation_rpls_log_id_type
# geolocalisation_rpls_org_id_type
# geolocalisation_immatriculation_copropriete_type

# %%
et.write(write_path, pretty_print=True, xml_declaration=True, encoding='utf-8')

# %%
print(etree.tostring(annotation,pretty_print=True).decode())
# Out:
# <xs:annotation xmlns:xs="http://www.w3.org/2001/XMLSchema" xmlns:vc="http://www.w3.org/2007/XMLSchema-versioning">
#   <xs:documentation>type de la propri&#233;t&#233; : compl_ref_logement</xs:documentation>
# </xs:annotation>

# %%
print(etree.tostring(simple_type,pretty_print=True).decode())
# Out:
# <xs:simpleType xmlns:xs="http://www.w3.org/2001/XMLSchema" xmlns:vc="http://www.w3.org/2007/XMLSchema-versioning" name="compl_ref_logement_type">
#   <xs:annotation>
#     <xs:documentation>type de la propri&#233;t&#233; : compl_ref_logement</xs:documentation>
#   </xs:annotation>
#   <xs:restriction base="xs:string">
#     <xs:maxLength value="255"/>
#   </xs:restriction>
# </xs:simpleType>

# %%
simple_type = copy.copy(el.find('xs:simpleType', namespaces=namespaces))
appinfo = el.find('xs:annotation/xs:appinfo', namespaces=namespaces)

# %%
appinfo.text

# %%
list(el.find('xs:complexType', namespaces=namespaces))
# Out:
# [<Element {http://www.w3.org/2001/XMLSchema}all at 0x2e4d3274a80>]

# %%
el.getchildren()
# Out:
# [<Element {http://www.w3.org/2001/XMLSchema}annotation at 0x2e4d2fbc300>,
#  <Element {http://www.w3.org/2001/XMLSchema}complexType at 0x2e4d2fbc3c0>]

# %% [markdown]
# ## load excel

# %%
path = Path("..")/"modele_donnee"

# %%
df_mdd=pd.read_excel(path/'modele_donnee.xlsx')
df_mdd = df_mdd[['description','nom_variable','parent_xpath','type','condition','DPE NEUF']]

enum_table = pd.read_excel(path/'enum_tables.xlsx', sheet_name=None)

valeur_table = pd.read_excel(path/'valeur_tables.xlsx', sheet_name=None)
valeur_table['coef_masque_lointain_non_homogene']=valeur_table['coef_masque_lointain_non_homoge']
del valeur_table['coef_masque_lointain_non_homoge']
enums=[el for el in df_mdd.nom_variable.dropna().values.tolist() if el.startswith('enum')]
enums_without_id =[el for el in enums if not el.endswith('id')]
enums_without_id
# Out:
# []

# %%
df_mdd['parent_xpath_neuf']=df_mdd['parent_xpath'].str.replace('dpe.logement.','dpe.logement_neuf.')
# Out:
# <ipython-input-6-0717af5c96b9>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_mdd['parent_xpath_neuf']=df_mdd['parent_xpath'].str.replace('dpe.logement.','dpe.logement_neuf.')

# %%
df_mdd['condition'] = (df_mdd.condition=='requis').replace({True:'requis',False:'optionnel'})

# %%
null = (df_mdd['DPE NEUF']=='non demandé')|(df_mdd['DPE NEUF'].isnull())
df_mdd.loc[null,'parent_xpath_neuf']=np.nan

# %%
enums_dict = {k:v.astype(str).set_index('id').lib.str.strip().str.lower().to_dict() for k,v in enum_table.items() if 'lib' in v and 'id' in v}
enums_dict['classe_etiquette']={k:v.upper() for k,v in enums_dict['classe_etiquette'].items()}
for k,v in enums_dict.items():
    for k1,v1 in v.items():
        if isinstance(v1,str):
            v[k1]=v1.replace('\xa0',' ')

with open(path/'enums.json','w',encoding='utf-8') as f:
    json.dump(enums_dict,f,indent=4,ensure_ascii=False)

# %%
mdd=df_mdd.dropna(subset=['nom_variable']).to_dict(orient='records')

# %%
mdd_neuf = [el.copy() for el in mdd if el['parent_xpath_neuf'] is not np.nan]

# %%
for el in mdd_neuf:
    el['parent_xpath']=el['parent_xpath_neuf']
    condition = el['DPE NEUF']
    if condition !="requis":
        condition = 'optionnel'
    el['condition']=condition

# %%
mdd.extend(mdd_neuf)

# %% [markdown]
# ## load xsd

# %%
from lxml.etree import ElementTree,XMLSchema
from lxml import etree
parser = etree.XMLParser(remove_blank_text=True)

path_xsd = r'..\modele_donnee\DPE_complet.xsd'
#path_xsd = r'.\DPE_dev.xsd'
schema=XMLSchema(file=path_xsd)

# %%
parser = etree.XMLParser(remove_blank_text=True)

et=etree.parse(path_xsd, parser)
root = et.getroot()

# %%
xs='{http://www.w3.org/2001/XMLSchema}'
namespaces = {'xs':'http://www.w3.org/2001/XMLSchema'}

# %%
logement = root.xpath('//xs:element[@name="logement"]', namespaces=namespaces)[0]

a_list = list()
for el in ['enveloppe', 'ventilation_collection',
           'installation_chauffage_collection',
           'installation_ecs_collection', 'climatisation_collection',
           'production_elec_enr', 'deperdition', 'apport_et_besoin', 'meteo']:
    el = logement.xpath(f'.//xs:element[@name="{el}"]', namespaces=namespaces)[0]
    for t in el.xpath('.//xs:element', namespaces=namespaces):
        if t.attrib['name'].startswith('enum_') and t.attrib.get('minOccurs') is None:
            a_list.append(t)

# %%
doc
# Out:
# []

# %%
all_req_enums=list()
for el in a_list:
    
    appinfo = el.xpath('./xs:annotation/xs:appinfo', namespaces=namespaces)
    doc = el.xpath('./xs:annotation/xs:documentation', namespaces=namespaces)

    if appinfo is not None:
        appinfo=appinfo[0]
        doc=doc[0].text
        all_req_enums.append({'nom':el.attrib['name'],'doc':doc,
        'source':appinfo.attrib['source']})

# %%
# Out:
#   File "<ipython-input-61-6f8a05283c66>", line 1
#     requis par la méthode 3cl (pas de calcul expert possible)
#            ^
# SyntaxError: invalid syntax

# %%
pd.DataFrame(all_req_enums).to_excel('resume_enum_requis.xlsx')

# %%
doc
# Out:
# <Element {http://www.w3.org/2001/XMLSchema}documentation at 0x1f9c523e880>

# %%
el.attrib
# Out:
# {'name': 'enum_classe_inertie_id'}

# %%
[0].attrib
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-26-50af4ececc83> in <module>
# ----> 1 el.xpath('./xs:annotation/xs:appinfo', namespaces=namespaces)[0].attrib
#
# IndexError: list index out of range

# %%
all_doc = list(root.iterfind(f'*//xs:documentation',namespaces=namespaces))

for doc in all_doc:
    txt=doc.text.replace('\n','').strip()
    txt = ' '.join(txt.split())
    doc.text=txt

# %%
et.write('test.xsd', pretty_print=True, xml_declaration=True, encoding='utf-8')

# %%
all_el = list(root.iterfind('*//xs:element',namespaces=namespaces))

# %%
all_doc = list(root.iterfind('*//xs:documentation',namespaces=namespaces))

for doc in all_doc:
    txt=doc.text.replace('\n','').strip()
    doc.text=txt

# %%
list_keys=list()
list_var=list()
for i,el in enumerate(all_el):
#     if el.attrib.get('name')=='annee_construction':
#         qdsqds
    caracs=dict(el.attrib)
    caracs['self']=el
    if 'name' in caracs:
        is_complex =len([child for child in el.getchildren() if 'complexType' in str(child.tag)])>0
        if not is_complex:
            doc = el.find(f'xs:annotation/xs:documentation',namespaces=namespaces)
            if doc is not None : 
                caracs.update({'documentation':doc.text})
            appinfo=el.find(f'xs:annotation/xs:appinfo',namespaces=namespaces)
            if appinfo is not None:
                caracs.update(appinfo.attrib)
                if appinfo.text is not None:
                    caracs.update({'appinfo':appinfo.text})
            restriction = el.find(f'xs:simpleType/xs:restriction',namespaces=namespaces)
            if restriction is not None:
                caracs.update(restriction.attrib)
                if len(restriction.getchildren())>=2 and restriction.attrib.get('base')=='xs:int':
                    caracs.update({'len_enum':np.max([int(el.attrib['value']) for el in restriction.getchildren() if not 'pattern' in str(el.tag)])})
            list_var.append(caracs)
for el in list_var:
    if el.get('minOccurs')=='0':
        el['condition']='optionnel'
    else:
        el['condition']='requis'

# keys=set(list_keys)

# for k,v in dict_var.items():
#     for i in set(keys)-set(v.keys()):
#         v[i]=''
#     dict_var[k]=v

# dict_new = dict()
# for k,v in dict_var.items():
#     v_new=dict()
#     for i in keys:
#         v_new[i]=v[i]
#     dict_new[k]=v_new

# %%
dpe_neuf=[el for el in list_var if 'logement_neuf' in el.get('source','')]

# %% [markdown]
# # load and update version

# %%
import yaml

with open('../versions.yml','r') as f:
    versions = yaml.load(f)
# Out:
# <ipython-input-23-3bcc7b947093>:4: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   versions = yaml.load(f)

# %%
v = versions['model']
model_version = f"Version V{v['version']} - {v['date']} : {v['titre']}"

# %%
dpe=root.xpath(f'//xs:element[@name="dpe"]',namespaces=namespaces)[0]
doc=dpe.xpath('xs:annotation/xs:documentation',namespaces=namespaces)[0]
doc.text=model_version

# %% [markdown]
# # check diffs

# %% [markdown]
# ## variables

# %%
name_var_u=df_mdd.nom_variable.unique()

# %%
for el in list_var:
    el['xpath']=el.get('source','')
    
for el in mdd:
    el['xpath']=el['parent_xpath'].replace('.','/')+'/'+el["nom_variable"]

# %%
print('==================not found IN XSD=================')

for el in sorted(list(set([el['xpath'] for el in mdd])-set([el['xpath'] for el in list_var]))):
    print(el)
# Out:
# ==================not found IN XSD=================
# dpe/administratif/diagnostiqueur/usr_diagnostiqueur_id
# dpe/administratif/geolocalisation/adresses/adresse_bien/adresse_proprietaire/adresse_proprietaire_installation_commune/adresse_brut
# dpe/administratif/geolocalisation/adresses/adresse_bien/adresse_proprietaire/adresse_proprietaire_installation_commune/ban_city
# dpe/administratif/geolocalisation/adresses/adresse_bien/adresse_proprietaire/adresse_proprietaire_installation_commune/ban_citycode
# dpe/administratif/geolocalisation/adresses/adresse_bien/adresse_proprietaire/adresse_proprietaire_installation_commune/ban_date_appel
# dpe/administratif/geolocalisation/adresses/adresse_bien/adresse_proprietaire/adresse_proprietaire_installation_commune/ban_housenumber
# dpe/administratif/geolocalisation/adresses/adresse_bien/adresse_proprietaire/adresse_proprietaire_installation_commune/ban_id
# dpe/administratif/geolocalisation/adresses/adresse_bien/adresse_proprietaire/adresse_proprietaire_installation_commune/ban_label
# dpe/administratif/geolocalisation/adresses/adresse_bien/adresse_proprietaire/adresse_proprietaire_installation_commune/ban_postcode
# dpe/administratif/geolocalisation/adresses/adresse_bien/adresse_proprietaire/adresse_proprietaire_installation_commune/ban_score
# dpe/administratif/geolocalisation/adresses/adresse_bien/adresse_proprietaire/adresse_proprietaire_installation_commune/ban_street
# dpe/administratif/geolocalisation/adresses/adresse_bien/adresse_proprietaire/adresse_proprietaire_installation_commune/ban_type
# dpe/administratif/geolocalisation/adresses/adresse_bien/adresse_proprietaire/adresse_proprietaire_installation_commune/ban_x
# dpe/administratif/geolocalisation/adresses/adresse_bien/adresse_proprietaire/adresse_proprietaire_installation_commune/ban_y
# dpe/administratif/geolocalisation/adresses/adresse_bien/adresse_proprietaire/adresse_proprietaire_installation_commune/code_postal_brut
# dpe/administratif/geolocalisation/adresses/adresse_bien/adresse_proprietaire/adresse_proprietaire_installation_commune/compl_etage_appartement
# dpe/administratif/geolocalisation/adresses/adresse_bien/adresse_proprietaire/adresse_proprietaire_installation_commune/compl_nom_residence
# dpe/administratif/geolocalisation/adresses/adresse_bien/adresse_proprietaire/adresse_proprietaire_installation_commune/compl_ref_batiment
# dpe/administratif/geolocalisation/adresses/adresse_bien/adresse_proprietaire/adresse_proprietaire_installation_commune/compl_ref_cage_escalier
# dpe/administratif/geolocalisation/adresses/adresse_bien/adresse_proprietaire/adresse_proprietaire_installation_commune/compl_ref_logement
# dpe/administratif/geolocalisation/adresses/adresse_bien/adresse_proprietaire/adresse_proprietaire_installation_commune/enum_statut_geocodage_ban_id
# dpe/administratif/geolocalisation/adresses/adresse_bien/adresse_proprietaire/adresse_proprietaire_installation_commune/label_brut
# dpe/administratif/geolocalisation/adresses/adresse_bien/adresse_proprietaire/adresse_proprietaire_installation_commune/nom_commune_brut
# dpe/logement/climatisation_collection/climatisation/donnee_entree/emetteur_plancher_fr
# dpe/logement_neuf/installation_ecs_collection/installation_ecs/donnee_entree/nombre_niveau_installation_ecs
# dpe/logement_neuf/rsee/rsee
# dpe/logement_neuf/rset/rset

# %%
print('==================not found IN XLSX=================')

for el in sorted(list(set([el['xpath'] for el in list_var])-set([el['xpath'] for el in mdd]))):
    print(el)
# Out:
# ==================not found IN XLSX=================
#
# dpe/administratif/geolocalisation/adresses/adresse_bien
# dpe/administratif/geolocalisation/adresses/adresse_proprietaire
# dpe/administratif/geolocalisation/adresses/adresse_proprietaire_installation_commune
# dpe/logement_neuf/climatisation_collection/climatisation/donnee_entree/enum_type_energie_id
# dpe/logement_neuf/sortie/qualite_isolation/qualite_isol_plancher_haut_comble_perdu
# dpe/logement_neuf/sortie/qualite_isolation/qualite_isol_plancher_haut_toit_terrasse

# %%
print('==================not found IN XSD=================')

for el in mdd:
    name = el['nom_variable']
    found = [el for el in list_var if el['name']==name]
    if len(found)==0:
        print(el['xpath'])
# Out:
# ==================not found IN XSD=================
# dpe/administratif/diagnostiqueur/usr_diagnostiqueur_id
# dpe/logement/climatisation_collection/climatisation/donnee_entree/emetteur_plancher_fr
# dpe/logement_neuf/rset/rset
# dpe/logement_neuf/rsee/rsee

# %%
for el in mdd:
    name = el['nom_variable']
    found = [el for el in list_var if el['name']==name]
    if len(found)==1:
        found = found[0]
        if 'source' in found:
            if found['source'].strip()!=el['xpath'].strip():

                print(f'=============wrong xpath for {el["nom_variable"]}=========')
                print('MDD XPATH : '+el['xpath'])
                print('XSD XPATH : '+found['source'])
            
            if found.get('documentation','NONE').lower().strip()!=el['description'].lower().strip():
                print(f'======================== NOT SAME DOC FOR {found["name"]}====================')
                print('=============DESC MDD ============')
                print(el['description'])
                print('=============DESC XSD ============')
                print(found.get('documentation','NONE'))
# Out:
# ======================== NOT SAME DOC FOR entreprise_diagnostiqueur====================
# =============DESC MDD ============
# entreprise du diagnostiqueur
# =============DESC XSD ============
# nom d'entreprise du diagnostiqueur du diagnostiqueur
# ======================== NOT SAME DOC FOR fe1====================
# =============DESC MDD ============
# fe1 facteur d'ensoleillement  calculé à partir de la table sur les masques proches
# =============DESC XSD ============
# fe1 facteur d'ensoleillement calculé à partir de la table sur les masques proches
# ======================== NOT SAME DOC FOR rendement_generation_stockage====================
# =============DESC MDD ============
# RgxRs : rendement de génération x rendement de stockage pour les systèmes pour lesquels le ballon est intégré au système de production ou réseau de chaleur   (0-1,5)
# =============DESC XSD ============
# RgxRs : rendement de génération x rendement de stockage pour les systèmes pour lesquels le ballon est intégré au système de production ou réseau de chaleur (0-1,5)
# ======================== NOT SAME DOC FOR rendement_regulation====================
# =============DESC MDD ============
# Rr : rendement de régulation du système de chauffage  (0-1)
# =============DESC XSD ============
# Rr : rendement de régulation du système de chauffage (0-1)
# ======================== NOT SAME DOC FOR tv_rendement_generation_id====================
# =============DESC MDD ============
# id de la ligne de la table utilisée pour le calcul  des rendements de générations forfaitaires des générateurs autres qu'à combustion
# =============DESC XSD ============
# id de la ligne de la table utilisée pour le calcul des rendements de générations forfaitaires des générateurs autres qu'à combustion
# ======================== NOT SAME DOC FOR tv_temp_fonc_100_id====================
# =============DESC MDD ============
# id de la ligne de la table utilisée pour le calcul  de la température à 100% de charge du système à combustion
# =============DESC XSD ============
# id de la ligne de la table utilisée pour le calcul de la température à 100% de charge du système à combustion
# ======================== NOT SAME DOC FOR tv_temp_fonc_30_id====================
# =============DESC MDD ============
# id de la ligne de la table utilisée pour le calcul  de la température à 30% de charge du système à combustion
# =============DESC XSD ============
# id de la ligne de la table utilisée pour le calcul de la température à 30% de charge du système à combustion
# ======================== NOT SAME DOC FOR conso_auxiliaire_distribution_fr====================
# =============DESC MDD ============
# consommation annuelle  d'auxilliaires de distribution de froid en energie finale (kWhef/an)
# =============DESC XSD ============
# consommation annuelle d'auxilliaires de distribution de froid en energie finale (kWhef/an)
# ======================== NOT SAME DOC FOR ep_conso_auxiliaire_distribution_fr====================
# =============DESC MDD ============
# consommation annuelle  d'auxilliaires de distribution de froid en energie primaire (kWhep/an)
# =============DESC XSD ============
# consommation annuelle d'auxilliaires de distribution de froid en energie primaire (kWhep/an)
# ======================== NOT SAME DOC FOR emission_ges_auxiliaire_generation_ch====================
# =============DESC MDD ============
# estimation GES d'auxilliaires de génération de chauffage  (kgCO2/an)
# =============DESC XSD ============
# estimation GES d'auxilliaires de génération de chauffage (kgCO2/an)
# ======================== NOT SAME DOC FOR emission_ges_auxiliaire_generation_ch_depensier====================
# =============DESC MDD ============
# estimation GES d'auxilliaires de génération de chauffage  pour le scénario dépensier (kgCO2/an)
# =============DESC XSD ============
# estimation GES d'auxilliaires de génération de chauffage pour le scénario dépensier (kgCO2/an)
# ======================== NOT SAME DOC FOR emission_ges_auxiliaire_distribution_ch====================
# =============DESC MDD ============
# estimation GES d'auxilliaires de distribution de chauffage  (kgCO2/an)
# =============DESC XSD ============
# estimation GES d'auxilliaires de distribution de chauffage (kgCO2/an)
# ======================== NOT SAME DOC FOR emission_ges_auxiliaire_generation_ecs====================
# =============DESC MDD ============
# estimation GES d'auxillaires de generation d'ECS  (kgCO2/an)
# =============DESC XSD ============
# estimation GES d'auxillaires de generation d'ECS (kgCO2/an)
# ======================== NOT SAME DOC FOR emission_ges_auxiliaire_generation_ecs_depensier====================
# =============DESC MDD ============
# estimation GES d'auxillaires de generation d'ECS  pour le scénario dépensier (kgCO2/an)
# =============DESC XSD ============
# estimation GES d'auxillaires de generation d'ECS pour le scénario dépensier (kgCO2/an)
# ======================== NOT SAME DOC FOR emission_ges_auxiliaire_distribution_ecs====================
# =============DESC MDD ============
# estimation GES d'auxilliaires de distribution d'ECS  (kgCO2/an)
# =============DESC XSD ============
# estimation GES d'auxilliaires de distribution d'ECS (kgCO2/an)
# ======================== NOT SAME DOC FOR emission_ges_auxiliaire_distribution_fr====================
# =============DESC MDD ============
# estimation GES  d'auxilliaires de distribution de froid  (kgCO2/an)
# =============DESC XSD ============
# estimation GES d'auxilliaires de distribution de froid (kgCO2/an)
# ======================== NOT SAME DOC FOR cout_auxiliaire_generation_ch====================
# =============DESC MDD ============
# coût des auxilliaires de génération de chauffage  (€)
# =============DESC XSD ============
# coût des auxilliaires de génération de chauffage (€)
# ======================== NOT SAME DOC FOR cout_auxiliaire_generation_ch_depensier====================
# =============DESC MDD ============
# coût des auxilliaires de génération de chauffage  pour le scénario dépensier (€)
# =============DESC XSD ============
# coût des auxilliaires de génération de chauffage pour le scénario dépensier (€)
# ======================== NOT SAME DOC FOR cout_auxiliaire_distribution_ch====================
# =============DESC MDD ============
# coût des auxilliaires de distribution de chauffage  (€)
# =============DESC XSD ============
# coût des auxilliaires de distribution de chauffage (€)
# ======================== NOT SAME DOC FOR cout_auxiliaire_generation_ecs====================
# =============DESC MDD ============
# coût des auxillaires de generation de l'ECS  (€)
# =============DESC XSD ============
# coût des auxillaires de generation de l'ECS (€)
# ======================== NOT SAME DOC FOR cout_auxiliaire_generation_ecs_depensier====================
# =============DESC MDD ============
# coût des auxillaires de generation de l'ECS  pour le scénario dépensier (€)
# =============DESC XSD ============
# coût des auxillaires de generation de l'ECS pour le scénario dépensier (€)
# ======================== NOT SAME DOC FOR cout_auxiliaire_distribution_ecs====================
# =============DESC MDD ============
# coût des auxilliaires de distribution de l'ECS  (€)
# =============DESC XSD ============
# coût des auxilliaires de distribution de l'ECS (€)
# ======================== NOT SAME DOC FOR cout_auxiliaire_distribution_fr====================
# =============DESC MDD ============
# coût  des auxilliaires de distribution de froid  (€)
# =============DESC XSD ============
# coût des auxilliaires de distribution de froid (€)
# ======================== NOT SAME DOC FOR conso_elec_ac_autre_usage====================
# =============DESC MDD ============
# éléctricité photovoltaique autoconsommée pour les autres usages de l'éléctricité  (kWhep/an)
# =============DESC XSD ============
# éléctricité photovoltaique autoconsommée pour les autres usages de l'éléctricité (kWhep/an)
# ======================== NOT SAME DOC FOR emission_ges====================
# =============DESC MDD ============
# estimation ges totale rapportée à la surface  (kgCO2/m²/an)
# =============DESC XSD ============
# estimation ges totale rapportée à la surface (kgCO2/m²/an)
# ======================== NOT SAME DOC FOR frais_annuels_energie====================
# =============DESC MDD ============
# frais d'energies associés  à la consommation (en euros)
# =============DESC XSD ============
# frais d'energies associés à la consommation (en euros)
# =============wrong xpath for nombre_niveau_installation_ecs=========
# MDD XPATH : dpe/logement_neuf/installation_ecs_collection/installation_ecs/donnee_entree/nombre_niveau_installation_ecs
# XSD XPATH : dpe/logement/installation_ecs_collection/installation_ecs/donnee_entree/nombre_niveau_installation_ecs

# %%
for el in mdd:
    name = el['nom_variable']
    found = [el for el in list_var if el['name']==name]
    if len(found)==0:
        print('==================not found=================')
        print(el['xpath'])
    elif len(found)==1:
        found = found[0]
        if 'source' in found:
            if found['source']!=el['xpath']:
                print(f'=============wrong xpath for {el["nom_variable"]}=========')
                print(el['xpath'],found['source'])
                
            if reformat(found.get('documentation','NONE'))!=reformat(el['description']):
                print(f'======================== NOT SAME DOC FOR {found["name"]}====================')
                print('=============DESC MDD ============')
                print(el['description'])
                print('=============DESC XSD ============')
                print(found.get('documentation','NONE'))
    elif len(found)>1:
        same_varname = [el for el in mdd if el['nom_variable']==name]
        xpath_mdd=set([el['xpath'] for el in same_varname])
        xpath_xsd = set([el.get('source') for el in found])
        if len(xpath_mdd&xpath_xsd)!=len(xpath_mdd):
            print ('================= WRONG XPATH POUR VARIABLE DUPLIQUE =============')
            print('================== VARIABLE DANS MDD =====================')
            for el in same_varname:
                print(el['xpath'])
            
            print('================== VARIABLE DANS XSD =====================')
            for el in found:
                if 'source' in el:
                    print(el['source'])
                else:
                    print('MISSING SOURCE FOR')
                    print(el['name'])
# Out:
# ==================not found=================
# dpe/administratif/diagnostiqueur/usr_diagnostiqueur_id
# ======================== NOT SAME DOC FOR entreprise_diagnostiqueur====================
# =============DESC MDD ============
# entreprise du diagnostiqueur
# =============DESC XSD ============
# nom d'entreprise du diagnostiqueur du diagnostiqueur
# ==================not found=================
# dpe/logement/climatisation_collection/climatisation/donnee_entree/emetteur_plancher_fr
# ==================not found=================
# dpe/logement_neuf/rset/rset
# ==================not found=================
# dpe/logement_neuf/rsee/rsee
# =============wrong xpath for nombre_niveau_installation_ecs=========
# dpe/logement_neuf/installation_ecs_collection/installation_ecs/donnee_entree/nombre_niveau_installation_ecs dpe/logement/installation_ecs_collection/installation_ecs/donnee_entree/nombre_niveau_installation_ecs

# %%
for el in [el for el in list_var if el['name'] not in name_var_u ]:
    print(f'variable not found in MDD : {el["name"]}')
# Out:
# variable not found in MDD : adresse_bien
# variable not found in MDD : adresse_proprietaire
# variable not found in MDD : adresse_proprietaire_installation_commune

# %% [markdown]
# ## enums

# %%
enums_mdd = [el['nom_variable'] for el in mdd if el['nom_variable'].startswith('enum_')]

# %%
enums_xsd_name = [el['name'] for el in list_var if el['name'].startswith('enum_')]

# %%
enums_xsd = [el for el in list_var if el['name'].startswith('enum_')]

# %%
enums_xsd_name_dict = dict()
for el in list_var:
    if el['name'].startswith('enum_'):
        if len(el.get('appinfo',''))>0:
            try:
                enums_xsd_name_dict[el['name'].replace('enum_','').replace('_id','')]=json.loads(el['appinfo'].replace('\n','').strip())
            except Exception as e:
                print('JSON NOT PARSED')
                print(el['name'])
                print(el['appinfo'])

# %%
for k,v in enums_xsd_name_dict.items():
    new_dict = dict()
    for k1,v1 in v.items():
        new_dict[k1.lower().strip()]=v1.lower().strip()

# %%
def reformat(x):
    x=x.lower().strip()
    x = ' '.join(x.split())
    return x

def reformat_dict(d):
    d=d.copy()
    for k,v in d.items():
        d[k]=reformat(v)
    return d

# %%
for enum_name,enum_dict in enums_dict.items():
    if enum_name not in enums_xsd_name_dict:
        print(enum_name,' NOT FOUND IN XSD')
    elif reformat_dict(enums_xsd_name_dict[enum_name])!=reformat_dict(enum_dict):
        enum_xsd=enums_xsd_name_dict[enum_name]
        print('DIFF BETWEEN ENUMS IN XSD AND MDD')
        print(f'MDD {enum_name}')
        print(f'DIFF WITH XSD {enum_name}')
        for k,v in enum_dict.items():
            if k not in enum_xsd:
                print('missing'+str({k:v}))
            elif reformat(v)!=reformat(enum_xsd[k]):
                print({k:(reformat(v),reformat(enum_xsd[k]))})
    elif enums_xsd_name_dict[enum_name]==enum_dict:
        print(f'GOOD MATCH :{enum_name}')
# Out:
# GOOD MATCH :version
# GOOD MATCH :modele_dpe
# GOOD MATCH :usage_fonctionnel_batiment
# GOOD MATCH :categorie_erp
# GOOD MATCH :methode_application_dpe_log
# GOOD MATCH :methode_application_dpe_ter
# GOOD MATCH :periode_construction
# GOOD MATCH :periode_isolation
# GOOD MATCH :zone_climatique
# GOOD MATCH :classe_altitude
# GOOD MATCH :methode_saisie_u
# GOOD MATCH :methode_saisie_u0
# GOOD MATCH :methode_saisie_uporte
# GOOD MATCH :methode_saisie_pont_thermique
# GOOD MATCH :methode_saisie_perf_vitrage
# GOOD MATCH :methode_saisie_carac_sys
# GOOD MATCH :methode_saisie_q4pa_conv
# GOOD MATCH :methode_saisie_fact_couv_sol
# GOOD MATCH :classe_inertie
# GOOD MATCH :type_adjacence
# GOOD MATCH :cfg_isolation_lnc
# GOOD MATCH :materiaux_structure_mur
# GOOD MATCH :type_isolation
# GOOD MATCH :type_plancher_bas
# GOOD MATCH :type_plancher_haut
# GOOD MATCH :type_vitrage
# GOOD MATCH :inclinaison_vitrage
# GOOD MATCH :type_materiaux_menuiserie
# GOOD MATCH :type_baie
# GOOD MATCH :type_pose
# GOOD MATCH :type_gaz_lame
# GOOD MATCH :orientation
# GOOD MATCH :type_fermeture
# GOOD MATCH :type_porte
# GOOD MATCH :type_liaison
# GOOD MATCH :type_ventilation
# GOOD MATCH :periode_installation_fr
# GOOD MATCH :type_generateur_fr
# GOOD MATCH :type_installation_solaire
# GOOD MATCH :type_installation
# GOOD MATCH :methode_calcul_conso
# GOOD MATCH :usage_generateur
# GOOD MATCH :cfg_installation_ch
# GOOD MATCH :lien_generateur_emetteur
# GOOD MATCH :cfg_installation_ecs
# GOOD MATCH :type_generateur_ch
# GOOD MATCH :type_emission_distribution
# GOOD MATCH :temp_distribution_ch
# GOOD MATCH :equipement_intermittence
# GOOD MATCH :type_regulation
# GOOD MATCH :type_chauffage
# GOOD MATCH :type_generateur_ecs
# GOOD MATCH :bouclage_reseau_ecs
# GOOD MATCH :type_stockage_ecs
# GOOD MATCH :periode_installation_ecs_thermo
# GOOD MATCH :type_enr
# GOOD MATCH :orientation_pv
# GOOD MATCH :inclinaison_pv
# GOOD MATCH :type_energie
# GOOD MATCH :type_usage
# classe_etiquette  NOT FOUND IN XSD
# GOOD MATCH :statut_geocodage_ban
# qualite_composant  NOT FOUND IN XSD
# GOOD MATCH :position_etage_logement
# GOOD MATCH :typologie_logement
# GOOD MATCH :categorie_enr_descriptif
# GOOD MATCH :categorie_descriptif_simplifie
# GOOD MATCH :categorie_fiche_technique
# GOOD MATCH :num_pack_travaux
# GOOD MATCH :lot_travaux
# GOOD MATCH :type_justificatif
# GOOD MATCH :origine_donnee
# GOOD MATCH :picto_geste_entretien
# GOOD MATCH :indicateur_confort_ete

# %% [markdown]
# # edit enum

# %%
with open(path/'deleted_enums.json','r',encoding='utf-8') as f:
    deleted_enums=json.load(f)

def apply_restriction_enum(simpletype,name,value_dict):
    restriction=simpletype.find('xs:restriction',namespaces=namespaces)
    if restriction is not None:
        simpletype.remove(restriction)
    restriction=SubElement(simpletype,f"{xs}restriction")
    restriction.attrib.update({"base":'xs:int'})
    enum_values = [int(el) for el in value_dict[name]]
    deleted_enums_values = deleted_enums.get(name,[])
    enum_values = set(enum_values)-set(deleted_enums_values_)
    enum_range = range(min(enum_values),max(enum_values)+1)
    if set(enum_values)!=set(enum_range):
        for value in enum_values:
            enumeration=SubElement(restriction,f"{xs}enumeration")
            enumeration.attrib.update({'value':value})
    else:
        min_value = min(enum_values)
        max_value = max(enum_values)
        minInclusive=SubElement(restriction,f"{xs}minInclusive")
        minInclusive.attrib.update({'value':str(min_value)})
        maxInclusive=SubElement(restriction,f"{xs}maxInclusive")
        maxInclusive.attrib.update({'value':str(max_value)})

# %%
enum_values = {k:list(v.keys()) for k,v in enums_dict.items()}

# %%
for el in enums_xsd:
    enum_name = el.get('name').replace('enum_','').replace('_id','')
    self = el['self']
    if enum_name in enums_dict:
        # restrictions
        if self.attrib.get('type','').startswith('s_'):
            s_type = self.attrib['type']
            s = root.xpath(f'//xs:simpleType[@name="{s_type}"]',namespaces=namespaces)[0]
            apply_restriction_enum(s,enum_name,enum_values)
            appinfo=s.find(f'xs:annotation/xs:appinfo',namespaces=namespaces)
            appinfo.text='\n'+json.dumps(enums_dict[enum_name],ensure_ascii=False,indent=4)+'\n'
        else:
            if self.attrib.get('type') is not None:
                raise Exception(f'{enum_name} should not have a type')
            else:
                simpletype = self.find('xs:simpleType',namespaces=namespaces)
                if simpletype is not None:
                    self.remove(simpletype)
                simpletype=SubElement(self,f"{xs}simpleType") 
                apply_restriction_enum(simpletype,enum_name,enum_values)
        # doc
        appinfo=self.find(f'xs:annotation/xs:appinfo',namespaces=namespaces)
        appinfo.text='\n'+json.dumps(enums_dict[enum_name],ensure_ascii=False,indent=4)+'\n'
    else:
        raise Exception(f'{enum_name} not found')

# %%
special_mapping={'classe_etiquette':'s_classe_etiquette',
'qualite_composant':'s_qualite'}

# %% [markdown]
# # edit doc

# %%
for el in list_var:
    eq_var = [x for x in mdd if el['xpath']==x['xpath']]

    if len(eq_var)>=1:
        doc = ' '.join(eq_var[0]['description'].split()).strip()
        self = el['self']
        documentation=self.find(f'xs:annotation/xs:documentation',namespaces=namespaces)
        if documentation is not None:
            documentation.text = doc
        else:
            annotation=self.find(f'xs:annotation',namespaces=namespaces)
            documentation = SubElement(annotation,f'{xs}documentation')
            documentation.text = doc
    else:

        print('not directly found', el['name'])
# Out:
# not directly found enum_type_energie_id
# not directly found qualite_isol_plancher_haut_toit_terrasse
# not directly found qualite_isol_plancher_haut_comble_perdu
# not directly found entreprise_diagnostiqueur
# not directly found adresse_bien
# not directly found adresse_proprietaire
# not directly found adresse_proprietaire_installation_commune
# not directly found adresse_brut
# not directly found code_postal_brut
# not directly found nom_commune_brut
# not directly found label_brut
# not directly found enum_statut_geocodage_ban_id
# not directly found ban_date_appel
# not directly found ban_id
# not directly found ban_label
# not directly found ban_housenumber
# not directly found ban_street
# not directly found ban_citycode
# not directly found ban_postcode
# not directly found ban_city
# not directly found ban_type
# not directly found ban_score
# not directly found ban_x
# not directly found ban_y
# not directly found compl_nom_residence
# not directly found compl_ref_batiment
# not directly found compl_etage_appartement
# not directly found compl_ref_cage_escalier
# not directly found compl_ref_logement

# %% [markdown]
# # edit tv

# %%
tv_range = {f'tv_{k}_id':v[f'tv_{k}_id'].max() for k,v in valeur_table.items()}

# %%
tv_values = {f'tv_{k}_id':v[f'tv_{k}_id'].values for k,v in valeur_table.items()}

# %%
tv_var = [el for el in list_var if el['name'].startswith('tv_')]

# %%
from lxml.etree import SubElement

# %%
for tv in tv_var:
    self = tv['self']
    tv_name = self.get('name')
    if tv_name in tv_values:
        # restrictions

        if self.attrib.get('type') is not None:
            raise Exception(f'{enum_name} should not have a type')
        else:
            simpletype = self.find('xs:simpleType',namespaces=namespaces)
            if simpletype is not None:
                self.remove(simpletype)
            simpletype=SubElement(self,f"{xs}simpleType") 
            apply_restriction_enum(simpletype,tv_name,tv_values)
    else:
        raise Exception(f'{tv_name} not found')

# %% [markdown]
# # transform type double en double positif

# %%
import lxml

# %%
double=etree.Element(f"{xs}simpleType")

# %%
restriction = SubElement(double,f"{xs}restriction")
restriction.attrib.update(dict(base="xs:double"))
minInclusive = SubElement(restriction,f"{xs}minInclusive")
minInclusive.attrib.update(dict(value="0"))

# %%
import copy
copy.copy(double)
# Out:
# <Element {http://www.w3.org/2001/XMLSchema}simpleType at 0x24b913050c0>

# %%
for el in root.xpath('//xs:element[@type="xs:double"]',namespaces=namespaces):
    el.append(copy.copy(double))
    del el.attrib['type']

# %% [markdown]
# # write

# %% [markdown]
# ## DPE COMPLET

# %%
if WRITE_IN_PLACE is True:
    et.write(str((path/'DPE_complet.xsd').absolute()), pretty_print=True, xml_declaration=True, encoding='utf-8')
else:
    et.write('DPE_complet.xsd', pretty_print=True, xml_declaration=True, encoding='utf-8')

# %% [markdown]
# ## nillable

# %%
for el in root.xpath('//xs:element[@minOccurs="0"]',namespaces=namespaces):
    el.attrib.update({"nillable":"true"})

# %%
et.write('DPE_complet_nillable.xsd', pretty_print=True, xml_declaration=True, encoding='utf-8')

# %% [markdown]
# ## SET neuf optionnel

# %%
logement_neuf=root.xpath('//xs:element[@name="logement_neuf"]',namespaces=namespaces)[0]

for el in ['enveloppe','ventilation_collection',
           'installation_chauffage_collection',
           'installation_ecs_collection','climatisation_collection',
           'production_elec_enr','deperdition','apport_et_besoin','meteo']:
    el = logement_neuf.xpath(f'.//xs:element[@name="{el}"]',namespaces=namespaces)[0]
    el.attrib.update({'minOccurs':'0'})
    for t in el.xpath('.//xs:element',namespaces=namespaces):
        t.attrib.update({'minOccurs':'0'})
for el in root.xpath('//xs:element[@minOccurs="0"]',namespaces=namespaces):
    el.attrib.update({"nillable":"true"})

# %% [markdown]
# ## WRITE  neuf optionnel

# %%
if WRITE_IN_PLACE is True:
    et.write(str((path/'DPEv2.xsd').absolute()), pretty_print=True, xml_declaration=True, encoding='utf-8')
else:
    et.write('DPE_neuf_optionnel_nillable.xsd', pretty_print=True, xml_declaration=True, encoding='utf-8')

# %% [markdown]
# ## SET existant optionnel

# %%
logement=root.xpath('//xs:element[@name="logement"]',namespaces=namespaces)[0]

for el in ['enveloppe','ventilation_collection',
           'installation_chauffage_collection',
           'installation_ecs_collection','climatisation_collection',
           'production_elec_enr','deperdition','apport_et_besoin','meteo']:
    el = logement.xpath(f'.//xs:element[@name="{el}"]',namespaces=namespaces)[0]
    el.attrib.update({'minOccurs':'0'})
    for t in el.xpath('.//xs:element',namespaces=namespaces):
        t.attrib.update({'minOccurs':'0'})
for el in root.xpath('//xs:element[@minOccurs="0"]',namespaces=namespaces):
    el.attrib.update({"nillable":"true"})

# %%
# mise en optionnel de la méthode d'application du dpe tertiaire
enum_methode_application_dpe_ter=root.xpath('//xs:element[@name="enum_methode_application_dpe_ter_id"]',namespaces=namespaces)[0]

enum_methode_application_dpe_ter.attrib.update({'minOccurs':'0'})
enum_methode_application_dpe_ter.attrib.update({"nillable":"true"})

# %% [markdown]
# ## write tout optionnel

# %%
# if WRITE_IN_PLACE is True:
#     et.write(str((path/'DPE.xsd').absolute()), pretty_print=True, xml_declaration=True, encoding='utf-8')
# else:
#     et.write('DPE_tout_optionnel_nillable.xsd', pretty_print=True, xml_declaration=True, encoding='utf-8')

# %% [markdown]
# ## suppression des restrictions numériques

# %%
et

# %%
for element in root.xpath('//xs:element',namespaces=namespaces):
    if len(element.xpath('/xs:simpleType/xs:restriction',namespaces=namespaces))>0:
        qs
    if len(element.getchildren())>1:
        dsq
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-125-e8c249ccdce0> in <module>
#       3         qs
#       4     if len(element.getchildren())>1:
# ----> 5         dsq
#
# NameError: name 'dsq' is not defined

# %%
element.getchildren()
# Out:
# [<Element {http://www.w3.org/2001/XMLSchema}annotation at 0x279da763800>,
#  <Element {http://www.w3.org/2001/XMLSchema}complexType at 0x279da763dc0>]

# %%
element.xpath('/xs:simpleType/xs:restriction',namespaces=namespaces)
# Out:
# []

# %%
element.attrib
# Out:
# {'name': 'compl_ref_logement', 'type': 'xs:string', 'minOccurs': '0', 'nillable': 'true'}

# %%
element.getchildren()
# Out:
# [<Element {http://www.w3.org/2001/XMLSchema}annotation at 0x279db96b040>]

# %%
sp=restriction.getparent()

# %%
sp.getroottree().getroot()
# Out:
# <Element {http://www.w3.org/2001/XMLSchema}simpleType at 0x279dab5c3c0>

# %%
p=restriction.getparent()

# %%
p.getparent()

# %% [markdown]
# ## controle intégrité variables_requises

# %%
cols = list()
for k,v in enum_table.items():
    cols.extend(v.columns.tolist())

# %%
variables_requises = list()
logement=et.find('//xs:element[@name="logement"]',namespaces=namespaces)
for k,v in enum_table.items():
    if 'variables_requises' in v.columns:
        for enum in logement.iterfind(f'*//xs:element[@name="enum_{k}_id"]',namespaces=namespaces):
            for variable_requise in v.variables_requises.dropna().unique():
                if variable_requise.count('(')>1:
                    dsq
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-2f7326fe32fa> in <module>
#       6             for variable_requise in v.variables_requises.dropna().unique():
#       7                 if variable_requise.count('(')>1:
# ----> 8                     dsq
#       9
#
# NameError: name 'dsq' is not defined

# %% [markdown]
# # hash réseau de chaleur

# %%
import hashlib

# %%
hashlib.md5('toto1'.encode()).hexdigest()[0:6]

# %%
reseau_chaleur=valeur_table['reseau_chaleur']

# %%
reseau_chaleur['chaud_ou_froid'].fillna('NA').value_counts()

hash_=reseau_chaleur['departement'].astype(str).str.zfill(2)+reseau_chaleur['nom_reseau']+reseau_chaleur['chaud_ou_froid']

hash_=hash_.apply(lambda x:hashlib.md5(x.lower().strip().encode()).hexdigest()[0:6])

reseau_chaleur['hash_reseau']=hash_

# %%
reseau_chaleur['hash_reseau'].to_excel('test.xlsx')
