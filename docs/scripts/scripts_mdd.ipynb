# %% [markdown]
# # imports

# %%
import pandas as pd
from pathlib import Path

# %% [markdown]
# # load ressources

# %%
path = Path("..")/"modele_donnee"

# %%
enum_table = pd.read_excel(path/'enum_tables.xlsx', sheet_name=None,engine='openpyxl')

# %%
enum_table['version']
# Out:
#    id                          lib  arrete_methode  arrete_reseau_chaleur  \
# 0   1  version du 1er juillet 2021             NaN                    NaN
#
#    arrete_contenu_co2  arrete_prix_energie  version_xsd  version_tv  \
# 0                 NaN                  NaN          NaN         NaN
#
#    version_enum
# 0           NaN

# %%
df_mdd=pd.read_excel(path/'modele_donnee.xlsx')
df_mdd = df_mdd[['description','nom_variable','parent_xpath','type','condition','DPE NEUF']]

enum_table = pd.read_excel(path/'enum_tables.xlsx', sheet_name=None)

valeur_table = pd.read_excel(path/'valeur_tables.xlsx', sheet_name=None)
valeur_table['coef_masque_lointain_non_homogene']=valeur_table['coef_masque_lointain_non_homoge']
del valeur_table['coef_masque_lointain_non_homoge']
enums=[el for el in df_mdd.nom_variable.dropna().values.tolist() if el.startswith('enum')]
enums_without_id =[el for el in enums if not el.endswith('id')]
enums_without_id
# Out:
# []

# %%
enums_name = [el.replace('enum_','').replace('_id','') for el in enums]

# %%
set(enums_name)-enum_table.keys()
# Out:
# set()

# %%
enums_dict = {k:v.set_index('id').lib.to_dict() for k,v in enum_table.items() if 'lib' in v and 'id' in v}

# %%
r=range(int(min(v.keys())),int(max(v.keys())))

# %%
for k,v in enums_dict.items():
    try:
        r=range(int(min(v.keys())),int(max(v.keys())+1))
        if len(r)>len(v.keys()):
            print(k,'repeated enums')
        for i in r:
            if i not in v:
                print(k,i) 
        if min(r)!=1:
            print(k,'bad start')
    except Exception as e:
        print(k)
        print(v)
        print(e)
# Out:
# classe_etiquette
# {'A': 'A', 'B': 'B', 'C': 'C', 'D': 'D', 'E': 'E', 'F': 'F', 'G': 'G'}
# invalid literal for int() with base 10: 'A'

# %%
set(enums_name)-set(enums_dict)
# Out:
# set()

# %%
for k,v in enums_dict.items():
    for k1,v1 in v.items():
        if isinstance(v1,str):
            v[k1]=v1.replace('\xa0',' ')

with open(path/'enums.json','w',encoding='utf-8') as f:
    json.dump(enums_dict,f,indent=4,ensure_ascii=False)

# %%
tables_valeur_dict=df_mdd.loc[df_mdd.nom_variable.fillna('').str.startswith('tv_')][['description','nom_variable']]

# %%
tables_valeur_dict = tables_valeur_dict.to_dict(orient='records')

# %%
a_dict = dict()
for el in tables_valeur_dict:
    a_dict[el['nom_variable']]={"description":el['description']}

# %%
with open('tv_doc.json','w',encoding='utf-8') as f:
    json.dump(a_dict,f,indent=4,ensure_ascii=False)

# %%
len(a_dict)
# Out:
# 35

# %%
with pd.ExcelWriter(path/'2021 03 01 valeur_tables_v2.2.xlsx') as writer:

    for tv in f7([el['nom_variable'] for el in tables_valeur_dict]):
        id_ = tv
        name = tv.split('tv_')[-1].split('_id')[0]
        pd.DataFrame(columns=[id_,'valeur']).to_excel(writer,sheet_name=name[0:31],index=False)  
        if len(name)>31:
            print(name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-4ba7ae8882c8> in <module>
#       1 with pd.ExcelWriter(path/'2021 03 01 valeur_tables_v2.2.xlsx') as writer:
#       2
# ----> 3     for tv in f7([el['nom_variable'] for el in tables_valeur_dict]):
#       4         id_ = tv
#       5         name = tv.split('tv_')[-1].split('_id')[0]
#
# NameError: name 'f7' is not defined

# %%
def f7(seq):
    seen = set()
    seen_add = seen.add
    return [x for x in seq if not (x in seen or seen_add(x))]

# %%
tables_valeur_dict

# %%
len('coef_masque_lointain_non_homogene')
